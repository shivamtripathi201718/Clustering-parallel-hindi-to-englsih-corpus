# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-d1c3be2d-03c0-4d4a-ba7e-6384e0d728a5" name="files[]" multiple disabled />
#      <output id="result-d1c3be2d-03c0-4d4a-ba7e-6384e0d728a5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving en.txt to en.txt
# Saving hi.txt to hi (1).txt

# %%
fp = open("hi.txt", "r+")
documents = fp.readlines()[1:-1]
print(documents)
# Out:
# ['एक्सेर्साइसर पहुंचनीयता अन्वेषक\n', 'निचले पटल के लिए डिफोल्ट प्लग-इन खाका\n', 'ऊपरी पटल के लिए डिफोल्ट प्लग-इन खाका\n', 'उन प्लग-इनों की सूची जिन्हें डिफोल्ट रूप से निष्क्रिय किया गया है\n', 'अवधि को हाइलाइट रकें\n', 'पहुंचनीय आसंधि (नोड) को चुनते समय हाइलाइट बक्से की अवधि\n', 'सीमांत (बोर्डर) के रंग को हाइलाइट करें\n', 'हाइलाइट किए गए सीमांत का रंग और अपारदर्शिता। \n', 'भराई के रंग को हाइलाइट करें\n', 'हाइलाइट किया गया भराई का रंग और पारदर्शिता। \n', 'एपीआई विचरक\n', 'इस समय जिसे प्राप्त किया गया हो, उसकी विभिन्न विधियों (मेथड) में विचरण करें\n', 'निजी गुणों को छिपाएं\n', 'विधि\n', 'गुणधर्म\n', 'मान\n', 'आईपाइथन कन्सोल\n', 'इस समय चुने गए एक्सेसेबेल से काम लेने के लिए अंतर्क्रियात्मक कन्सोल\n', 'घटना मानिटर\n', 'घटनाओं को मानिटर करें (_ M) \n', 'चुनाव को हटाएं (C _) \n', 'सभी\n', 'चुने गए अनुप्रयोग\n', 'चुने गए एक्सेसेबेल\n', 'स्रोत\n', 'घटना मानिटर\n', 'चुने गए प्रकारों और स्रोतों से घटनाएं जैसे-जैसे घटित होती हैं, उन्हें दर्शाता है\n', 'अंतिम प्रविष्ट घटना को हाइलाइट करो\n', 'घटना रेकोर्डिंग शुरू करो/रोको\n', 'घटना रोजनामचा मिटाओ\n', 'कोई विवरण नहीं\n', 'वर्णन\n', 'दिखाएं\n', 'पहुंचनीय\n', 'कार्रवाई संपन्न करें\n', 'कार्रवाई (_ o) \n', 'आईडी\n', 'औजार बक्सा\n', 'संस्करण\n', 'अनुप्रयोग\n', 'संग्रह\n', '0, 0\n', 'सापेक्ष स्थिति\n', 'आकार\n', 'विडजेट\n', 'स्तर\n', 'एमडीआई-जेड-क्रम\n', 'अल्फा\n', 'निरपेक्ष स्थिति\n', 'घटक\n', 'डेस्कटोप\n', 'स्थान-विशिष्टः\n', 'प्रलेख\n', 'हाइपरकड़ी\n', 'हाइपरपाठ\n', 'स्थिति\n', 'वर्णन\n', 'स्थान-विशिष्ट\n', 'छवि (_ I) \n', 'प्रवेश सहायक\n', 'सभी चुनें\n', 'चयन (_ S) \n', 'प्रवाहित करनेयोग्य विषयवस्तु\n', 'चुने गए स्तंभ\n', 'चुनी गई पंक्तियां\n', 'स्तंभ\n', 'पंक्तियां\n', '& lt; bgt; सारणी सूचनाlt;/bgt; \n', 'नाम (x, y) \n', 'शीर्षकः\n', 'विस्तारः\n', 'पंक्ति\n', 'स्तंभ\n', '& lt; bgt; चुनी गई कोशिकाlt;/bgt; \n', 'सारणी (_ T) \n', 'ओफसेट\n', 'डिफोल्टों को शामिल करें\n', 'पाठ (_ x) \n', 'मौजूदा मान\n', 'न्यूनतम वृद्धि\n', 'अधिकतम मान\n', 'न्यूनतम मान\n', 'मान\n', 'अंतराफलक दर्शक\n', 'अंतराफलक के विभिन्न गुणों को देखने देता है\n', '(क्रियान्वित नहीं हुआ है) \n', 'नाम\n', 'यूआरआई\n', 'प्रारंभ\n', 'अंत\n', 'बहुत अधिक चयनीय शिशु हैं\n', 'तेज चुनाव\n', 'प्लग-इन जिसमें हैं एक्सेसेबेलों को तेजी से चुनने के लिए कई विधियां\n', 'अंतिम बार फोकस किए गए एक्सेसेबल को जांचें\n', 'माउस के अधीन जो एक्सेसेबल है, उसे जांचें\n', 'वतनी\n', 'श्वानपुच्छ\n', 'एलडीटीपी\n', 'लिपि प्रकार\n', 'लिपि रेकोर्डर\n', 'श्वानपुच्छ शैली की लिपियां निर्मित करता है\n', 'वर्तमान लिपि (स्क्रिप्ट) खो जाएगी। \n', 'मिटाने की पुष्टि करें\n', 'स्कीमाः\n', 'सत्यापन\n', 'खाली\n', 'कोई विवरण नहीं\n', 'एटी-एसपीआई सत्यापक\n', 'अनुप्रयोग की पहुंचनीयता का सत्यापन करता है\n', 'स्तर\n', 'भूमिका\n', 'सहेज रहे हैं\n', 'पुष्टि कर रहे हैं\n', 'अपवाद\n', 'त्रुटि\n', 'चेतावनी\n', 'सूचना\n', 'दोषमुक्त करें\n', 'मूल\n', 'मूलभूत जीयूआई अनुप्रयोग पहुंचनीयता का परीक्षण करता है\n', '% s जिस पर कार्रवाई हो सकती है, वह न तो फोकस करने योग्य है न ही चयनीय\n', 'अंतर्क्रियात्मक% s कार्रवाई करने योग्य नहीं है\n', 'एक से अधिक विडजेट फोकस में है\n', '% s का कोई पाठ अंतराफलक नहीं है\n', 'अभिभावक में% s सूची शिशु सूची सेमेल नहीं खाती\n', '% s संबंध के लिए अन्योन्य गायब है\n', '% s गायब नाम या सूचक\n', 'फोकस योग्य% s में सारणी अंतराफलक है, कोई चयनीय अंतराफलक नहीं हैbutton has focused state without focusable state\n', '% s में% s स्थिति है, पर उसके साथ% s स्थिति नहीं है\n', '% s किसी समुच्चय का सदस्य नहीं है\n', '% (rolename) s सूची% (num) d पंक्ति और स्तंभ से मेल नहीं खातेparent indexrow and column index\n', '% (rolename) s अभिभावक सूची% (num1) d पंक्ति और स्तंभ सूची% (num2) d से मेल नहीं खाते\n', '% s का कोई नाम या विवरण नहीं\n', 'पसंद (_ P)... \n', 'विषय सूची (_ C) \n', 'एक्सेरसाइसर आपके डेस्कटोप में मौजूद अनुप्रयोग नहीं देख पाया। इस समस्या के समाधान के लिए आपको डेस्कटोप पहुंचनीयता को सक्रिय करना होगा। क्या आप इसे सक्रिय करना चाहते हैं? \n', 'टिप्पणीः परिवर्तन सत्रांत (लोगआउट) के बाद ही प्रभाव में आएंगे। \n', 'शिशु\n', 'पंजी ताजा करें (_ R) \n', 'सभी को ताजा करें\n', 'आसंधि (नोड) को ताजा करें (_ N) \n', 'चुनी गई आसंधियों (नोड) के शिशुओं को ताजा करें\n', 'घटक\n', 'कार्य ...

# %%
 
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from sklearn.metrics import adjusted_rand_score

# documents = ["This little kitty came to play when I was eating at a restaurant.",
#              "Merley has the best squooshy kitten belly.",
#              "Google Translate app is incredible.",
#              "If you open 100 tab in google you get a smiley face.",
#              "Best cat photo I've ever taken.",
#              "Climbing ninja cat.",
#              "Impressed with google map feedback.",
#              "Key promoter extension for Google Chrome."]

vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(documents)

true_k = 200
model = KMeans(n_clusters=true_k, init='k-means++', max_iter=100, n_init=1)
model.fit(X)

print("Top terms per cluster:")
order_centroids = model.cluster_centers_.argsort()[:, ::-1]
terms = vectorizer.get_feature_names()
for i in range(true_k):
    print("Cluster %d:" % i),
    for ind in order_centroids[i, :10]:
        print(' %s' % terms[ind]),
    print

print("\n")
print("Prediction")

Y = vectorizer.transform(["chrome browser to open."])
prediction = model.predict(Y)
print(prediction)

Y = vectorizer.transform(["My cat is hungry."])
prediction = model.predict(Y)
print(prediction)
# Out:
# Top terms per cluster:
# Cluster 0:
#  रह
#  कर
#  हत
#  एमड
#  एप
#  एट
#  एग
#  एकल
#  एक
#  ऊपर
# Cluster 1:
#  हत
#  उपलब
#  एम
#  एप
#  एट
#  एग
#  एकल
#  एक
#  ऊपर
#  उसक
# Cluster 2:
#  लग
#  इन
#  हत
#  उस
#  एम
#  एप
#  एट
#  एग
#  एकल
#  एक
# Cluster 3:
#  बल
#  तक
#  गए
#  एक
#  कर
#  हत
#  उन
#  एट
#  एग
#  एकल
# Cluster 4:
#  कर
#  हत
#  एलड
#  एम
#  एप
#  एट
#  एग
#  एकल
#  एक
#  ऊपर
# Cluster 5:
#  नतम
#  हत
#  घटन
#  एम
#  एप
#  एट
#  एग
#  एकल
#  एक
#  ऊपर
# Cluster 6:
#  नह
#  हत
#  घटन
#  एम
#  एप
#  एट
#  एग
#  एकल
#  एक
#  ऊपर
# Cluster 7:
#  रय
#  गए
#  अन
#  हत
#  उपलब
#  एप
#  एट
#  एग
#  एकल
#  एक
# Cluster 8:
#  टर
#  घटन
#  कर
#  उपलब
#  एम
#  एप
#  एट
#  एग
#  एकल
#  एक
# Cluster 9:
#  णन
#  वर
#  हत
#  उस
#  एम
#  एप
#  एट
#  एग
#  एकल
#  एक
# Cluster 10:
#  बक
#  इट
#  इल
#  हत
#  उस
#  एम
#  एप
#  एट
#  एग
#  एकल
# Cluster 11:
#  षक
#  हत
#  एलड
#  एम
#  एप
#  एट
#  एग
#  एकल
#  एक
#  ऊपर
# Cluster 12:
#  पथ
#  हत
#  घटन
#  एम
#  एप
#  एट
#  एग
#  एकल
#  एक
#  ऊपर
# Cluster 13:
#  वरण
#  नह
#  हत
#  एमड
#  एप
#  एट
#  एग
#  एकल
#  एक
#  ऊपर
# Cluster 14:
#  तक
#  कर
#  हत
#  उस
#  एम
#  एप
#  एट
#  एग
#  एकल
#  एक
# Cluster 15:
#  चन
#  हत
#  उपलब
#  एम
#  एप
#  एट
#  एग
#  एकल
#  एक
#  ऊपर
# Cluster 16:
#  आस
#  गई
#  कर
#  उपलब
#  एप
#  एट
#  एग
#  एकल
#  एक
#  ऊपर
# Cluster 17:
#  घटक
#  उपलब
#  एम
#  एप
#  एट
#  एग
#  एकल
#  एक
#  ऊपर
#  उसक
# Cluster 18:
#  नय
#  हत
#  घटन
#  एम
#  एप
#  एट
#  एग
#  एकल
#  एक
#  ऊपर
# Cluster 19:
#  अप
#  रदर
#  और
#  गए
#  इट
#  इल
#  हत
#  उस
#  एट
#  एग
# Cluster 20:
#  lt
#  bgt
#  रण
#  चन
#  हत
#  एम
#  एप
#  एट
#  एग
#  एकल
# Cluster 21:
#  ऊपर
#  पटल
#  हत
#  घटन
#  एम
#  एप
#  एट
#  एग
#  एकल
#  एक
# Cluster 22:
#  सभ
#  हत
#  उपलब
#  एम
#  एप
#  एट
#  एग
#  एकल
#  एक
#  ऊपर
# Cluster 23:
#  तर
#  हत
#  एलड
#  एम
#  एप
#  एट
#  एग
#  एकल
#  एक
#  ऊपर
# Cluster 24:
#  घटन
#  रव
#  इट
#  इल
#  कर
#  एप
#  एट
#  एग
#  एकल
#  एक
# Cluster 25:
#  आईड
#  हत
#  उपलब
#  एम
#  एप
#  एट
#  एग
#  एकल
#  एक
#  ऊपर
# Cluster 26:
#  गए
#  हत
#  उपलब
#  एम
#  एप
#  एट
#  एग
#  एकल
#  एक
#  ऊपर
# Cluster 27:
#  पस
#  हत
#  उपलब
#  एम
#  एप
#  एट
#  एग
#  एकल
#  एक
#  ऊपर
# Cluster 28:
#  षय
#  रक
#  हत
#  एप
#  एट
#  एग
#  एकल
#  एक
#  ऊपर
#  उसक
# Cluster 29:
#  अवध
#  रक
#  इट
#  इल
#  उपलब
#  एप
#  एट
#  एग
#  एकल
#  एक
# Cluster 30:
#  हट
#  घटन
#  एमड
#  एम
#  एप
#  एट
#  एग
#  एकल
#  एक
#  ऊपर
# Cluster 31:
#  पन
#  रव
#  कर
#  हत
#  एट
#  एग
#  एकल
#  एक
#  ऊपर
#  उसक
# Cluster 32:
#  णधर
#  हत
#  एलड
#  एम
#  एप
#  एट
#  एग
#  एकल
#  एक
#  ऊपर
# Cluster 33:
#  खन
#  फलक
#  तर
#  हत
#  उपलब
#  एप
#  एट
#  एग
#  एकल
#  एक
# Cluster 34:
#  डज
#  हत
#  उपलब
#  एम
#  एप
#  एट
#  एग
#  एकल
#  एक
#  ऊपर
# Cluster 35:
#  चयन
#  हत
#  उपलब
#  एम
#  एप
#  एट
#  एग
#  एकल
#  एक
#  ऊपर
# Cluster 36:
#  इपरप
#  हत
#  उपलब
#  एम
#  एप
#  एट
#  एग
#  एकल
#  एक
#  ऊपर
# Cluster 37:
#  रम
#  एमड
#  आई
#  हत
#  उपलब
#  एप
#  एट
#  एग
#  एकल
#  एक
# Cluster 38:
#  उस
#  बल
#  अध
#  एक
#  हत
#  एम
#  एप
#  एट
#  एग
#  एकल
# Cluster 39:
#  इसर
#  यत
#  षक
#  पह
#  अन
#  चन
#  एक
#  उपलब
#  एट
#  एग
# Cluster 40:
#  आईप
#  इथन
#  कन
#  हत
#  उपलब
#  एप
#  एट
#  एग
#  एकल
#  एक
# Cluster 41:
#  रव
#  हत
#  आल
#  एम
#  एप
#  एट
#  एग
#  एकल
#  एक
#  ऊपर
# Cluster 42:
#  भर
#  इट
#  इल
#  कर
#  हत
#  एप
#  एट
#  एग
#  एकल
#  एक
# Cluster 43:
#  इपरकड
#  हत
#  उपलब
#  एम
#  एप
#  एट
#  एग
#  एकल
#  एक
#  ऊपर
# Cluster 44:
#  षयवस
#  करन
#  रव
#  इसर
#  एट
#  एग
#  एकल
#  एक
#  ऊपर
#  उसक
# Cluster 45:
#  करण
#  हत
#  एलड
#  एम
#  एप
#  एट
#  एग
#  एकल
#  एक
#  ऊपर
# Cluster 46:
#  रल
#  हत
#  आल
#  एम
#  एप
#  एट
#  एग
#  एकल
#  एक
#  ऊपर
# Cluster 47:
#  state
#  फलक
#  तर
#  button
#  has
#  focused
#  focusable
#  without
#  रण
#  कस
# Cluster 48:
#  अल
#  आल
#  एम
#  एप
#  एट
#  एग
#  एकल
#  एक
#  ऊपर
#  उसक
# Cluster 49:
#  गई
#  हत
#  उपलब
#  एम
#  एप
#  एट
#  एग
#  एकल
#  एक
#  ऊपर
# Cluster 50:
#  ओफस
#  हत
#  एलड
#  एम
#  एप
#  एट
#  एग
#  एकल
#  एक
#  ऊपर
# Cluster 51:
#  शक
#  दर
#  फलक
#  तर
#  उपलब
#  एप
#  एट
#  एग
#  एकल
#  एक
# Cluster 52:
#  बह
#  चयन
#  अध
#  हत
#  उपलब
#  एप
#  एट
#  एग
#  एकल
#  एक
# Cluster 53:
#  बह
#  चयन
#  अध
#  हत
#  उपलब
#  एप
#  एट
#  एग
#  एकल
#  एक
# Cluster 54:
#  आक
#  हत
#  उपलब
#  एम
#  एप
#  एट
#  एग
#  एकल
#  एक
#  ऊपर
# Cluster 55:
#  कट
#  हत
#  एलड
#  एम
#  एप
#  एट
#  एग
#  एकल
#  एक
#  ऊपर
# Cluster 56:
#  डर
#  इट
#  इल
#  कर
#  उस
#  एम
#  एप
#  एट
#  एग
#  एकल
# Cluster 57:
#  रप
#  हत
#  उपलब
#  एम
#  एप
#  एट
#  एग
#  एकल
#  एक
#  ऊपर
# Cluster 58:
#  एप
#  चरक
#  आई
#  हत
#  उपलब
#  एम
#  एट
#  एग
#  एकल
#  एक
# Cluster 59:
#  औज
#  बक
#  हत
#  उपलब
#  एप
#  एट
#  एग
#  एकल
#  एक
#  ऊपर
# Cluster 60:
#  रण
#  हत
#  उपलब
#  एम
#  एप
#  एट
#  एग
#  एकल
#  एक
#  ऊपर
# Cluster 61:
#  नप
#  करत
#  एमड
#  एप
#  एट
#  एग
#  एकल
#  एक
#  ऊपर
#  उसक
# Cluster 62:
#  चल
#  पटल
#  लग
#  इन
#  हत
#  उस
#  एप
#  एट
#  एग
#  एकल
# Cluster 63:
#  करत
#  पन
#  सत
#  यत
#  रय
#  पह
#  अन
#  चन
#  इसर
#  एकल
# Cluster 64:
#  कतम
#  अध
#  हत
#  एमड
#  एप
#  एट
#  एग
#  एकल
#  एक
#  ऊपर
# Cluster 65:
#  नन
#  कई
#  सम
#  लग
#  इन
#  एक
#  हत
#  उस
#  एट
#  एग
# Cluster 66:
#  छव
#  हत
#  उपलब
#  एम
#  एप
#  एट
#  एग
#  एकल
#  एक
#  ऊपर
# Cluster 67:
#  pluginview
#  नल
#  आउट
#  हत
#  उस
#  एम
#  एप
#  एट
#  एग
#  एकल
# Cluster 68:
#  घट
#  दर
#  उन
#  रक
#  और
#  घटन
#  गए
#  उपलब
#  एट
#  एग
# Cluster 69:
#  कन
#  मक
#  समय
#  इस
#  तर
#  गए
#  एक
#  हत
#  एट
#  एग
# Cluster 70:
#  उन
#  गय
#  लग
#  इन
#  उपलब
#  एप
#  एट
#  एग
#  एकल
#  एक
# Cluster 71:
#  रय
#  अन
#  हत
#  एमड
#  एप
#  एट
#  एग
#  एकल
#  एक
#  ऊपर
# Cluster 72:
#  यब
#  अन
#  हत
#  उपलब
#  एप
#  एट
#  एग
#  एकल
#  एक
#  ऊपर
# Cluster 73:
#  नत
#  आस
#  अवध
#  समय
#  बक
#  पह
#  चन
#  इट
#  इल
#  इपरकड
# Cluster 74:
#  बह
#  चयन
#  अध
#  हत
#  उपलब
#  एप
#  एट
#  एग
#  एकल
#  एक
# Cluster 75:
#  इल
#  हत
#  उपलब
#  एम
#  एप
#  एट
#  एग
#  एकल
#  एक
#  ऊपर
# Cluster 76:
#  पस
#  इसर
#  एक
#  हत
#  उपलब
#  एम
#  एप
#  एट
#  एग
#  एकल
# Cluster 77:
#  गआउट
#  आए
#  तन
#  पण
#  रभ
#  सत
#  पर
#  वर
#  हत
#  उन
# Cluster 78:
#  षम
#  कर
#  हत
#  उस
#  एम
#  एप
#  एट
#  एग
#  एकल
#  एक
# Cluster 79:
#  एलड
#  हत
#  उपलब
#  एम
#  एप
#  एट
#  एग
#  एकल
#  एक
#  ऊपर
# Cluster 80:
#  चय
#  सदस
#  सम
#  नह
#  हत
#  उपलब
#  एप
#  एट
#  एग
#  एकल
# Cluster 81:
#  indexrow
#  num
#  and
#  column
#  parent
#  index
#  rolename
#  और
#  नह
#  एमड
# Cluster 82:
#  बल
#  कस
#  गए
#  एक
#  हत
#  उन
#  एप
#  एट
#  एग
#  एकल
# Cluster 83:
#  आईप
#  इथन
#  कन
#  हत
#  उपलब
#  एप
#  एट
#  एग
#  एकल
#  एक
# Cluster 84:
#  2006
#  गम
#  2007
#  सर
#  एम
#  आईब
#  एसड
#  इसर
#  एक
#  उसक
# Cluster 85:
#  धन
#  एलड
#  एमड
#  एम
#  एप
#  एट
#  एग
#  एकल
#  एक
#  ऊपर
# Cluster 86:
#  आरआई
#  उपलब
#  एम
#  एप
#  एट
#  एग
#  एकल
#  एक
#  ऊपर
#  उसक
# Cluster 87:
#  अपव
#  हत
#  आल
#  एम
#  एप
#  एट
#  एग
#  एकल
#  एक
#  ऊपर
# Cluster 88:
#  आल
#  एलड
#  एमड
#  एम
#  एप
#  एट
#  एग
#  एकल
#  एक
#  ऊपर
# Cluster 89:
#  state
#  फलक
#  तर
#  button
#  has
#  focused
#  focusable
#  without
#  रण
#  कस
# Cluster 90:
#  सक
#  आपक
#  कट
#  करन
#  इस
#  रस
#  हत
#  समस
#  आप
#  सम
# Cluster 91:
#  मदद
#  आल
#  एम
#  एप
#  एट
#  एग
#  एकल
#  एक
#  ऊपर
#  उसक
# Cluster 92:
#  वक
#  अभ
#  नह
#  एमड
#  एप
#  एट
#  एग
#  एकल
#  एक
#  ऊपर
# Cluster 93:
#  मक
#  करन
#  रव
#  तर
#  नह
#  हत
#  उपलब
#  एग
#  एकल
#  एक
# Cluster 94:
#  वन
#  हत
#  एलड
#  एम
#  एप
#  एट
#  एग
#  एकल
#  एक
#  ऊपर
# Cluster 95:
#  एट
#  एसप
#  पक
#  सत
#  आई
#  हत
#  उपलब
#  एग
#  एकल
#  एक
# Cluster 96:
#  रत
#  एसड
#  करण
#  नय
#  वरण
#  इस
#  और
#  चन
#  इल
#  हत
# Cluster 97:
#  सकत
#  वह
#  पर
#  कस
#  करन
#  चयन
#  रव
#  हत
#  उन
#  एग
# Cluster 98:
#  com
#  yahoo
#  तव
#  रमण
#  लस
#  raviratlami
#  rajeshkajha
#  gmail
#  यम
#  balasubramaniam
# Cluster 99:
#  फट
#  वत
#  उपलब
#  एम
#  एप
#  एट
#  एग
#  एकल
#  एक
#  ऊपर
# Cluster 100:
#  वतन
#  हत
#  एलड
#  एम
#  एप
#  एट
#  एग
#  एकल
#  एक
#  ऊपर
# Cluster 101:
#  उसक
#  पर
#  नह
#  हत
#  उपलब
#  एप
#  एट
#  एग
#  एकल
#  एक
# Cluster 102:
#  चक
#  यब
#  उपलब
#  एम
#  एप
#  एट
#  एग
#  एकल
#  एक
#  ऊपर
# Cluster 103:
#  इटन
#  इल
#  हत
#  उस
#  एम
#  एप
#  एट
#  एग
#  एकल
#  एक
# Cluster 104:
#  थल
#  हत
#  एलड
#  एम
#  एप
#  एट
#  एग
#  एकल
#  एक
#  ऊपर
# Cluster 105:
#  डज
#  कस
#  अध
#  एक
#  हत
#  उस
#  एम
#  एप
#  एट
#  एग
# Cluster 106:
#  पह
#  चन
#  हत
#  उन
#  एप
#  एट
#  एग
#  एकल
#  एक
#  ऊपर
# Cluster 107:
#  एग
#  तम
#  वर
#  हत
#  उस
#  एम
#  एप
#  एट
#  एकल
#  एक
# Cluster 108:
#  लगइन
#  हत
#  आल
#  एम
#  एप
#  एट
#  एग
#  एकल
#  एक
#  ऊपर
# Cluster 109:
#  भर
#  हत
#  उपलब
#  एम
#  एप
#  एट
#  एग
#  एकल
#  एक
#  ऊपर
# Cluster 110:
#  num2
#  num1
#  rolename
#  अभ
#  वक
#  और
#  नह
#  एम
#  एप
#  एट
# Cluster 111:
#  लभ
#  षण
#  करत
#  पर
#  आई
#  यत
#  रय
#  पह
#  अन
#  चन
# Cluster 112:
#  पन
#  सत
#  उन
#  एप
#  एट
#  एग
#  एकल
#  एक
#  ऊपर
#  उसक
# Cluster 113:
#  घटन
#  कर
#  एमड
#  एप
#  एट
#  एग
#  एकल
#  एक
#  ऊपर
#  उसक
# Cluster 114:
#  आईप
#  इथन
#  कन
#  हत
#  उपलब
#  एप
#  एट
#  एग
#  एकल
#  एक
# Cluster 115:
#  ऊपर
#  पटल
#  लग
#  इन
#  हत
#  उस
#  एप
#  एट
#  एग
#  एकल
# Cluster 116:
#  अपन
#  यत
#  रय
#  पह
#  अन
#  चन
#  हत
#  उपलब
#  एग
#  एकल
# Cluster 117:
#  टर
#  घटन
#  उपलब
#  एमड
#  एम
#  एप
#  एट
#  एग
#  एकल
#  एक
# Cluster 118:
#  सह
#  रह
#  हत
#  उन
#  एप
#  एट
#  एग
#  एकल
#  एक
#  ऊपर
# Cluster 119:
#  फलक
#  तर
#  नह
#  हत
#  उस
#  एप
#  एट
#  एग
#  एकल
#  एक
# Cluster 120:
#  एकल
#  लग
#  इन
#  हत
#  उस
#  एम
#  एप
#  एट
#  एग
#  एक
# Cluster 121:
#  इथन
#  मक
#  यत
#  षक
#  पह
#  तर
#  अन
#  चन
#  एक
#  उपलब
# Cluster 122:
#  अज
#  हत
#  आल
#  एम
#  एप
#  एट
#  एग
#  एकल
#  एक
#  ऊपर
# Cluster 123:
#  नप
#  हत
#  घटन
#  एम
#  एप
#  एट
#  एग
#  एकल
#  एक
#  ऊपर
# Cluster 124:
#  रक
#  हत
#  उपलब
#  एम
#  एप
#  एट
#  एग
#  एकल
#  एक
#  ऊपर
# Cluster 125:
#  डर
#  एलड
#  एम
#  एप
#  एट
#  एग
#  एकल
#  एक
#  ऊपर
#  उसक
# Cluster 126:
#  रब
#  तक
#  कर
#  हत
#  एप
#  एट
#  एग
#  एकल
#  एक
#  ऊपर
# Cluster 127:
#  भend
#  हत
#  उपलब
#  एम
#  एप
#  एट
#  एग
#  एकल
#  एक
#  ऊपर
# Cluster 128:
#  pluginviews
#  उपलब
#  नई
#  हत
#  उसक
#  एमड
#  एम
#  एप
#  एट
#  एग
# Cluster 129:
#  गणन
#  हत
#  उपलब
#  एम
#  एप
#  एट
#  एग
#  एकल
#  एक
#  ऊपर
# Cluster 130:
#  एकल
#  आउट
#  हत
#  उपलब
#  एम
#  एप
#  एट
#  एग
#  एक
#  ऊपर
# Cluster 131:
#  षय
#  हत
#  एलड
#  एम
#  एप
#  एट
#  एग
#  एकल
#  एक
#  ऊपर
# Cluster 132:
#  रह
#  हत
#  आल
#  एम
#  एप
#  एट
#  एग
#  एकल
#  एक
#  ऊपर
# Cluster 133:
#  तक
#  हत
#  एलड
#  एम
#  एप
#  एट
#  एग
#  एकल
#  एक
#  ऊपर
# Cluster 134:
#  आस
#  कर
#  एलड
#  एम
#  एप
#  एट
#  एग
#  एकल
#  एक
#  ऊपर
# Cluster 135:
#  चल
#  पटल
#  हत
#  उपलब
#  एप
#  एट
#  एग
#  एकल
#  एक
#  ऊपर
# Cluster 136:
#  भर
#  बक
#  इट
#  इल
#  हत
#  उपलब
#  एप
#  एट
#  एग
#  एकल
# Cluster 137:
#  अवध
#  इट
#  इल
#  हत
#  उस
#  एम
#  एप
#  एट
#  एग
#  एकल
# Cluster 138:
#  start
#  धन
#  एलड
#  एमड
#  एम
#  एप
#  एट
#  एग
#  एकल
#  एक
# Cluster 139:
#  सभ
#  कर
#  हत
#  उपलब
#  एम
#  एप
#  एट
#  एग
#  एकल
#  एक
# Cluster 140:
#  इसर
#  एक
#  हत
#  उपलब
#  एम
#  एप
#  एट
#  एग
#  एकल
#  ऊपर
# Cluster 141:
#  bgt
#  lt
#  गई
#  हत
#  उस
#  एम
#  एप
#  एट
#  एग
#  एकल
# Cluster 142:
#  रण
#  चन
#  हत
#  उन
#  एप
#  एट
#  एग
#  एकल
#  एक
#  ऊपर
# Cluster 143:
#  नल
#  आउट
#  हत
#  उस
#  एम
#  एप
#  एट
#  एग
#  एकल
#  एक
# Cluster 144:
#  आईप
#  इथन
#  कन
#  हत
#  उपलब
#  एप
#  एट
#  एग
#  एकल
#  एक
# Cluster 145:
#  रदर
#  भर
#  गय
#  और
#  इट
#  इल
#  उपलब
#  एट
#  एग
#  एकल
# Cluster 146:
#  बह
#  चयन
#  अध
#  हत
#  उपलब
#  एप
#  एट
#  एग
#  एकल
#  एक
# Cluster 147:
#  state
#  फलक
#  तर
#  button
#  has
#  focused
#  focusable
#  without
#  रण
#  कस
# Cluster 148:
#  एप
#  चरक
#  आई
#  हत
#  उपलब
#  एम
#  एट
#  एग
#  एकल
#  एक
# Cluster 149:
#  मच
#  जन
#  घटन
#  and
#  उस
#  एमड
#  एम
#  एप
#  एट
#  एग
# Cluster 150:
#  बल
#  कस
#  गए
#  एक
#  हत
#  उन
#  एप
#  एट
#  एग
#  एकल
# Cluster 151:
#  यक
#  सह
#  रव
#  हत
#  उन
#  एट
#  एग
#  एकल
#  एक
#  ऊपर
# Cluster 152:
#  गए
#  एक
#  हत
#  उपलब
#  एम
#  एप
#  एट
#  एग
#  एकल
#  ऊपर
# Cluster 153:
#  चल
#  पटल
#  लग
#  इन
#  हत
#  उस
#  एप
#  एट
#  एग
#  एकल
# Cluster 154:
#  एप
#  चरक
#  आई
#  हत
#  उपलब
#  एम
#  एट
#  एग
#  एकल
#  एक
# Cluster 155:
#  बल
#  कस
#  गए
#  एक
#  हत
#  उन
#  एप
#  एट
#  एग
#  एकल
# Cluster 156:
#  बल
#  कस
#  गए
#  एक
#  हत
#  उन
#  एप
#  एट
#  एग
#  एकल
# Cluster 157:
#  एप
#  चरक
#  आई
#  हत
#  उपलब
#  एम
#  एट
#  एग
#  एकल
#  एक
# Cluster 158:
#  चल
#  पटल
#  लग
#  इन
#  हत
#  उस
#  एप
#  एट
#  एग
#  एकल
# Cluster 159:
#  लग
#  इन
#  हत
#  उस
#  एम
#  एप
#  एट
#  एग
#  एकल
#  एक
# Cluster 160:
#  2006
#  गम
#  2007
#  सर
#  एम
#  आईब
#  एसड
#  इसर
#  एक
#  उसक
# Cluster 161:
#  थल
#  हत
#  एलड
#  एम
#  एप
#  एट
#  एग
#  एकल
#  एक
#  ऊपर
# Cluster 162:
#  पस
#  हत
#  उपलब
#  एम
#  एप
#  एट
#  एग
#  एकल
#  एक
#  ऊपर
# Cluster 163:
#  बल
#  तक
#  गए
#  एक
#  कर
#  हत
#  उन
#  एट
#  एग
#  एकल
# Cluster 164:
#  तक
#  कर
#  हत
#  उस
#  एम
#  एप
#  एट
#  एग
#  एकल
#  एक
# Cluster 165:
#  रब
#  तक
#  कर
#  हत
#  एप
#  एट
#  एग
#  एकल
#  एक
#  ऊपर
# Cluster 166:
#  थड
#  चरण
#  उसक
#  समय
#  गय
#  इस
#  कर
#  हत
#  उपलब
#  एप
# Cluster 167:
#  षक
#  हत
#  एलड
#  एम
#  एप
#  एट
#  एग
#  एकल
#  एक
#  ऊपर
# Cluster 168:
#  तक
#  कर
#  हत
#  उस
#  एम
#  एप
#  एट
#  एग
#  एकल
#  एक
# Cluster 169:
#  एकल
#  लग
#  इन
#  हत
#  उस
#  एम
#  एप
#  एट
#  एग
#  एक
# Cluster 170:
#  रय
#  अन
#  हत
#  एमड
#  एप
#  एट
#  एग
#  एकल
#  एक
#  ऊपर
# Cluster 171:
#  पथ
#  हत
#  घटन
#  एम
#  एप
#  एट
#  एग
#  एकल
#  एक
#  ऊपर
# Cluster 172:
#  com
#  yahoo
#  तव
#  रमण
#  लस
#  raviratlami
#  rajeshkajha
#  gmail
#  यम
#  balasubramaniam
# Cluster 173:
#  षक
#  हत
#  एलड
#  एम
#  एप
#  एट
#  एग
#  एकल
#  एक
#  ऊपर
# Cluster 174:
#  रय
#  अन
#  हत
#  एमड
#  एप
#  एट
#  एग
#  एकल
#  एक
#  ऊपर
# Cluster 175:
#  लग
#  इन
#  हत
#  उस
#  एम
#  एप
#  एट
#  एग
#  एकल
#  एक
# Cluster 176:
#  पथ
#  हत
#  घटन
#  एम
#  एप
#  एट
#  एग
#  एकल
#  एक
#  ऊपर
# Cluster 177:
#  लग
#  इन
#  हत
#  उस
#  एम
#  एप
#  एट
#  एग
#  एकल
#  एक
# Cluster 178:
#  हत
#  उपलब
#  एम
#  एप
#  एट
#  एग
#  एकल
#  एक
#  ऊपर
#  उसक
# Cluster 179:
#  नह
#  हत
#  घटन
#  एम
#  एप
#  एट
#  एग
#  एकल
#  एक
#  ऊपर
# Cluster 180:
#  तक
#  हत
#  एलड
#  एम
#  एप
#  एट
#  एग
#  एकल
#  एक
#  ऊपर
# Cluster 181:
#  भर
#  हत
#  उपलब
#  एम
#  एप
#  एट
#  एग
#  एकल
#  एक
#  ऊपर
# Cluster 182:
#  भर
#  बक
#  इट
#  इल
#  हत
#  उपलब
#  एप
#  एट
#  एग
#  एकल
# Cluster 183:
#  नय
#  हत
#  घटन
#  एम
#  एप
#  एट
#  एग
#  एकल
#  एक
#  ऊपर
# Cluster 184:
#  indexrow
#  num
#  and
#  column
#  parent
#  index
#  rolename
#  और
#  नह
#  एमड
# Cluster 185:
#  num2
#  num1
#  rolename
#  अभ
#  वक
#  और
#  नह
#  एम
#  एप
#  एट
# Cluster 186:
#  वरण
#  नह
#  हत
#  एमड
#  एप
#  एट
#  एग
#  एकल
#  एक
#  ऊपर
# Cluster 187:
#  पस
#  हत
#  उपलब
#  एम
#  एप
#  एट
#  एग
#  एकल
#  एक
#  ऊपर
# Cluster 188:
#  षय
#  हत
#  एलड
#  एम
#  एप
#  एट
#  एग
#  एकल
#  एक
#  ऊपर
# Cluster 189:
#  सक
#  आपक
#  कट
#  करन
#  इस
#  रस
#  हत
#  समस
#  आप
#  सम
# Cluster 190:
#  गआउट
#  आए
#  तन
#  पण
#  रभ
#  सत
#  पर
#  वर
#  हत
#  उन
# Cluster 191:
#  हत
#  उपलब
#  एम
#  एप
#  एट
#  एग
#  एकल
#  एक
#  ऊपर
#  उसक
# Cluster 192:
#  कर
#  हत
#  एलड
#  एम
#  एप
#  एट
#  एग
#  एकल
#  एक
#  ऊपर
# Cluster 193:
#  सभ
#  कर
#  हत
#  उपलब
#  एम
#  एप
#  एट
#  एग
#  एकल
#  एक
# Cluster 194:
#  आस
#  कर
#  एलड
#  एम
#  एप
#  एट
#  एग
#  एकल
#  एक
#  ऊपर
# Cluster 195:
#  आस
#  गई
#  कर
#  उपलब
#  एप
#  एट
#  एग
#  एकल
#  एक
#  ऊपर
# Cluster 196:
#  घटक
#  उपलब
#  एम
#  एप
#  एट
#  एग
#  एकल
#  एक
#  ऊपर
#  उसक
# Cluster 197:
#  हत
#  उपलब
#  एम
#  एप
#  एट
#  एग
#  एकल
#  एक
#  ऊपर
#  उसक
# Cluster 198:
#  हत
#  उपलब
#  एम
#  एप
#  एट
#  एग
#  एकल
#  एक
#  ऊपर
#  उसक
# Cluster 199:
#  आल
#  एलड
#  एमड
#  एम
#  एप
#  एट
#  एग
#  एकल
#  एक
#  ऊपर
#
#
# Prediction
# [1]
# [1]
# /usr/local/lib/python3.6/dist-packages/sklearn/cluster/k_means_.py:969: ConvergenceWarning: Number of distinct clusters (144) found smaller than n_clusters (200). Possibly due to duplicate points in X.
#   return_n_iter=True)

# %%
fp = open("en.txt", "r+")
documents = fp.readlines()[1:-1]
print(documents)
# Out:
# ['Accerciser Accessibility Explorer\n', 'The default plugin layout for the bottom panel\n', 'The default plugin layout for the top panel\n', 'A list of plugins that are disabled by default\n', 'Highlight duration\n', 'The duration of the highlight box when selecting accessible nodes\n', 'Highlight border color\n', 'The color and opacity of the highlight border.\n', 'Highlight fill color\n', 'The color and opacity of the highlight fill.\n', 'API Browser\n', 'Browse the various methods of the current accessible\n', 'Hide private attributes\n', 'Method\n', 'Property\n', 'Value\n', 'IPython Console\n', 'Interactive console for manipulating currently selected accessible\n', 'Event monitor\n', '_ Monitor Events\n', 'C _ lear Selection\n', 'Everything\n', 'Selected application\n', 'Selected accessible\n', 'Source\n', 'Event Monitor\n', 'Shows events as they occur from selected types and sources\n', 'Highlight last event entry\n', 'Start / stop event recording\n', 'Clear event log\n', '(no description)\n', 'Description\n', 'Show\n', '_ Accessible\n', 'Perform action\n', 'Acti _ on\n', 'ID\n', 'Toolkit\n', 'Version\n', 'Ap _ plication\n', 'Col _ lection\n', '0, 0\n', 'Relative position\n', 'Size\n', 'WIDGET\n', 'Layer\n', 'MDI - Z - order\n', 'Alpha\n', 'Absolute position\n', 'Co _ mponent\n', 'Des _ ktop\n', 'Locale:\n', '_ Document\n', 'Hyperlink\n', 'H _ ypertext\n', 'Position\n', 'Description\n', 'Locale\n', '_ Image\n', 'Lo _ gin Helper\n', 'Select All\n', '_ Selection\n', 'St _ reamable Content\n', 'Selected columns\n', 'Selected rows\n', 'Columns\n', 'Rows\n', 'Table Information\n', 'name (x, y)\n', 'Header:\n', 'Extents:\n', 'Row\n', 'Column\n', 'Selected Cell\n', '_ Table\n', 'Offset\n', 'Include defaults\n', 'Te _ xt\n', 'Current value\n', 'Minimum increment\n', 'Maximum value\n', 'Minimum value\n', 'Val _ ue\n', 'Interface Viewer\n', 'Allows viewing of various interface properties\n', '(not implemented)\n', 'Name\n', 'URI\n', 'Start\n', 'End\n', 'Too many selectable children\n', 'Quick Select\n', 'Plugin with various methods of selecting accessibles quickly.\n', 'Inspect last focused accessible\n', 'Inspect accessible under mouse\n', 'Native\n', 'Dogtail\n', 'LDTP\n', 'Script Type\n', 'Script Recorder\n', 'Creates dogtail style scripts\n', 'The current script will be lost.\n', 'Confirm clear\n', 'Sche _ ma:\n', 'V _ alidate\n', 'Idle\n', 'No description\n', 'AT - SPI Validator\n', 'Validates application accessibility\n', 'Level\n', 'Role\n', 'Saving\n', 'Validating\n', 'EXCEPT\n', 'ERROR\n', 'WARN\n', 'INFO\n', 'DEBUG\n', 'Basic\n', 'Tests fundamental GUI application accessibility\n', 'actionable% s is not focusable or selectable\n', 'interactive% s is not actionable\n', 'more than one focused widget\n', '% s has no text interface\n', '% s index in parent does not match child index\n', 'Missing reciprocal for% s relation\n', '% s missing name or label\n', 'focusable% s has table interface, no selection interface\n', '% s has% s state without% s state\n', '% s does not belong to a set\n', '% (rolename) s index% (num) d does not match row and column\n', '% (rolename) s parent index% (num1) d does not match row and column index% (num2) d\n', '% s has no name or description\n', '_ Preferences...\n', '_ Contents\n', 'Accerciser could not see the applications on your desktop. You must enable desktop accessibility to fix this problem. Do you want to enable it now?\n', 'Note: Changes only take effect after logout.\n', 'Children\n', '_ Refresh Registry\n', 'Refresh all\n', 'Refresh _ Node\n', "Refresh selected node 's children\n", 'Component\n', 'Task\n', 'Key\n', 'Alt\n', 'Ctrl\n', 'Shift\n', 'Top panel\n', 'Bottom panel\n', 'accerciser Preferences\n', 'Plugins\n', 'Global Hotkeys\n', 'Highlighting\n', 'Highlight duration:\n', 'Border color:\n', 'The border color of the highlight box\n', 'Fill color:\n', 'The fill color of the highlight box\n', 'translator - credits\n', 'An interactive Python accessibility explorer\n', 'accerciser C ...

# %%
 
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from sklearn.metrics import adjusted_rand_score

# documents = ["This little kitty came to play when I was eating at a restaurant.",
#              "Merley has the best squooshy kitten belly.",
#              "Google Translate app is incredible.",
#              "If you open 100 tab in google you get a smiley face.",
#              "Best cat photo I've ever taken.",
#              "Climbing ninja cat.",
#              "Impressed with google map feedback.",
#              "Key promoter extension for Google Chrome."]

vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(documents)

true_k = 200
model = KMeans(n_clusters=true_k, init='k-means++', max_iter=100, n_init=1)
model.fit(X)

print("Top terms per cluster:")
order_centroids = model.cluster_centers_.argsort()[:, ::-1]
terms = vectorizer.get_feature_names()
for i in range(true_k):
    print("Cluster %d:" % i),
    for ind in order_centroids[i, :10]:
        print(' %s' % terms[ind]),
    print

print("\n")
print("Prediction")

Y = vectorizer.transform(["chrome browser to open."])
prediction = model.predict(Y)
print(prediction)

Y = vectorizer.transform(["My cat is hungry."])
prediction = model.predict(Y)
print(prediction)
# Out:
# Top terms per cluster:
# Cluster 0:
#  validator
#  spi
#  at
#  fix
#  explorer
#  extents
#  file
#  files
#  fill
#  focusable
# Cluster 1:
#  application
#  selected
#  focused
#  extents
#  file
#  files
#  fill
#  fix
#  focusable
#  ypertext
# Cluster 2:
#  the
#  browse
#  methods
#  current
#  various
#  accessible
#  of
#  focused
#  files
#  fill
# Cluster 3:
#  events
#  monitor
#  ypertext
#  focused
#  file
#  files
#  fill
#  fix
#  focusable
#  for
# Cluster 4:
#  the
#  top
#  default
#  layout
#  panel
#  plugin
#  for
#  fix
#  extents
#  file
# Cluster 5:
#  or
#  has
#  description
#  name
#  no
#  focused
#  file
#  files
#  fill
#  fix
# Cluster 6:
#  start
#  ypertext
#  except
#  extents
#  file
#  files
#  fill
#  fix
#  focusable
#  focused
# Cluster 7:
#  value
#  everything
#  explorer
#  extents
#  file
#  files
#  fill
#  fix
#  focusable
#  focused
# Cluster 8:
#  the
#  opacity
#  fill
#  and
#  color
#  of
#  highlight
#  dogtail
#  from
#  fix
# Cluster 9:
#  edit
#  bookmarks
#  ypertext
#  for
#  file
#  files
#  fill
#  fix
#  focusable
#  focused
# Cluster 10:
#  single
#  plugins
#  view
#  ypertext
#  everything
#  explorer
#  extents
#  file
#  files
#  fill
# Cluster 11:
#  many
#  too
#  selectable
#  children
#  extents
#  file
#  files
#  fill
#  fix
#  focusable
# Cluster 12:
#  monitor
#  event
#  ypertext
#  focused
#  file
#  files
#  fill
#  fix
#  focusable
#  for
# Cluster 13:
#  relative
#  position
#  focusable
#  explorer
#  extents
#  file
#  files
#  fill
#  fix
#  ypertext
# Cluster 14:
#  accessible
#  selected
#  ypertext
#  extents
#  file
#  files
#  fill
#  fix
#  focusable
#  focused
# Cluster 15:
#  preferences
#  accerciser
#  focused
#  explorer
#  extents
#  file
#  files
#  fill
#  fix
#  focusable
# Cluster 16:
#  columns
#  ypertext
#  has
#  extents
#  file
#  files
#  fill
#  fix
#  focusable
#  focused
# Cluster 17:
#  locale
#  ypertext
#  for
#  extents
#  file
#  files
#  fill
#  fix
#  focusable
#  focused
# Cluster 18:
#  acti
#  on
#  for
#  extents
#  file
#  files
#  fill
#  fix
#  focusable
#  focused
# Cluster 19:
#  num
#  rolename
#  match
#  index
#  column
#  row
#  does
#  and
#  not
#  last
# Cluster 20:
#  quick
#  select
#  ypertext
#  focusable
#  explorer
#  extents
#  file
#  files
#  fill
#  fix
# Cluster 21:
#  type
#  content
#  focused
#  extents
#  file
#  files
#  fill
#  fix
#  focusable
#  ypertext
# Cluster 22:
#  title
#  ypertext
#  focused
#  extents
#  file
#  files
#  fill
#  fix
#  focusable
#  for
# Cluster 23:
#  ypertext
#  has
#  explorer
#  extents
#  file
#  files
#  fill
#  fix
#  focusable
#  focused
# Cluster 24:
#  add
#  bookmark
#  ypertext
#  for
#  file
#  files
#  fill
#  fix
#  focusable
#  focused
# Cluster 25:
#  duration
#  highlight
#  ypertext
#  focused
#  extents
#  file
#  files
#  fill
#  fix
#  focusable
# Cluster 26:
#  name
#  ypertext
#  explorer
#  file
#  files
#  fill
#  fix
#  focusable
#  focused
#  for
# Cluster 27:
#  rows
#  selected
#  give
#  fix
#  except
#  explorer
#  extents
#  file
#  files
#  fill
# Cluster 28:
#  border
#  color
#  ypertext
#  focused
#  file
#  files
#  fill
#  fix
#  focusable
#  for
# Cluster 29:
#  description
#  has
#  explorer
#  extents
#  file
#  files
#  fill
#  fix
#  focusable
#  focused
# Cluster 30:
#  size
#  everything
#  explorer
#  extents
#  file
#  files
#  fill
#  fix
#  focusable
#  focused
# Cluster 31:
#  plugin
#  view
#  ypertext
#  fix
#  explorer
#  extents
#  file
#  files
#  fill
#  focusable
# Cluster 32:
#  shows
#  occur
#  they
#  from
#  as
#  sources
#  types
#  events
#  and
#  selected
# Cluster 33:
#  all
#  select
#  ypertext
#  focused
#  extents
#  file
#  files
#  fill
#  fix
#  focusable
# Cluster 34:
#  recording
#  stop
#  start
#  event
#  ypertext
#  fix
#  extents
#  file
#  files
#  fill
# Cluster 35:
#  node
#  children
#  refresh
#  selected
#  focused
#  extents
#  file
#  files
#  fill
#  fix
# Cluster 36:
#  properties
#  allows
#  viewing
#  various
#  interface
#  of
#  ypertext
#  except
#  extents
#  file
# Cluster 37:
#  view
#  ypertext
#  focusable
#  explorer
#  extents
#  file
#  files
#  fill
#  fix
#  focused
# Cluster 38:
#  information
#  table
#  focusable
#  explorer
#  extents
#  file
#  files
#  fill
#  fix
#  focused
# Cluster 39:
#  end
#  ypertext
#  except
#  extents
#  file
#  files
#  fill
#  fix
#  focusable
#  focused
# Cluster 40:
#  document
#  ypertext
#  focused
#  extents
#  file
#  files
#  fill
#  fix
#  focusable
#  for
# Cluster 41:
#  lear
#  selection
#  ypertext
#  focusable
#  explorer
#  extents
#  file
#  files
#  fill
#  fix
# Cluster 42:
#  ypertext
#  has
#  explorer
#  extents
#  file
#  files
#  fill
#  fix
#  focusable
#  focused
# Cluster 43:
#  toolkit
#  ypertext
#  focused
#  extents
#  file
#  files
#  fill
#  fix
#  focusable
#  for
# Cluster 44:
#  header
#  has
#  explorer
#  extents
#  file
#  files
#  fill
#  fix
#  focusable
#  focused
# Cluster 45:
#  private
#  hide
#  attributes
#  focused
#  extents
#  file
#  files
#  fill
#  fix
#  focusable
# Cluster 46:
#  path
#  has
#  extents
#  file
#  files
#  fill
#  fix
#  focusable
#  focused
#  ypertext
# Cluster 47:
#  list
#  are
#  by
#  disabled
#  that
#  plugins
#  default
#  of
#  layout
#  focused
# Cluster 48:
#  action
#  perform
#  focused
#  extents
#  file
#  files
#  fill
#  fix
#  focusable
#  ypertext
# Cluster 49:
#  fill
#  color
#  ypertext
#  has
#  extents
#  file
#  files
#  fix
#  focusable
#  focused
# Cluster 50:
#  image
#  ypertext
#  except
#  extents
#  file
#  files
#  fill
#  fix
#  focusable
#  focused
# Cluster 51:
#  extents
#  ypertext
#  has
#  explorer
#  file
#  files
#  fill
#  fix
#  focusable
#  focused
# Cluster 52:
#  sche
#  ma
#  ypertext
#  focusable
#  explorer
#  extents
#  file
#  files
#  fill
#  fix
# Cluster 53:
#  ktop
#  des
#  ypertext
#  extents
#  file
#  files
#  fill
#  fix
#  focusable
#  focused
# Cluster 54:
#  layer
#  ypertext
#  focused
#  explorer
#  extents
#  file
#  files
#  fill
#  fix
#  focusable
# Cluster 55:
#  xt
#  te
#  ypertext
#  focusable
#  explorer
#  extents
#  file
#  files
#  fill
#  fix
# Cluster 56:
#  widget
#  ypertext
#  focused
#  explorer
#  extents
#  file
#  files
#  fill
#  fix
#  focusable
# Cluster 57:
#  increment
#  minimum
#  ypertext
#  focusable
#  extents
#  file
#  files
#  fill
#  fix
#  focused
# Cluster 58:
#  position
#  ypertext
#  has
#  extents
#  file
#  files
#  fill
#  fix
#  focusable
#  focused
# Cluster 59:
#  row
#  except
#  extents
#  file
#  files
#  fill
#  fix
#  focusable
#  focused
#  for
# Cluster 60:
#  entry
#  last
#  event
#  highlight
#  ypertext
#  focusable
#  extents
#  file
#  files
#  fill
# Cluster 61:
#  reamable
#  st
#  content
#  ypertext
#  extents
#  file
#  files
#  fill
#  fix
#  focusable
# Cluster 62:
#  property
#  ypertext
#  except
#  extents
#  file
#  files
#  fill
#  fix
#  focusable
#  focused
# Cluster 63:
#  method
#  ypertext
#  focused
#  extents
#  file
#  files
#  fill
#  fix
#  focusable
#  for
# Cluster 64:
#  everything
#  has
#  explorer
#  extents
#  file
#  files
#  fill
#  fix
#  focusable
#  focused
# Cluster 65:
#  id
#  ypertext
#  except
#  extents
#  file
#  files
#  fill
#  fix
#  focusable
#  focused
# Cluster 66:
#  log
#  clear
#  event
#  ypertext
#  file
#  files
#  fill
#  fix
#  focusable
#  focused
# Cluster 67:
#  focused
#  inspect
#  last
#  accessible
#  ypertext
#  extents
#  file
#  files
#  fill
#  fix
# Cluster 68:
#  mponent
#  co
#  explorer
#  extents
#  file
#  files
#  fill
#  fix
#  focusable
#  ypertext
# Cluster 69:
#  explorer
#  accerciser
#  accessibility
#  for
#  extents
#  file
#  files
#  fill
#  fix
#  focusable
# Cluster 70:
#  source
#  ypertext
#  explorer
#  extents
#  file
#  files
#  fill
#  fix
#  focusable
#  focused
# Cluster 71:
#  order
#  mdi
#  ypertext
#  focused
#  extents
#  file
#  files
#  fill
#  fix
#  focusable
# Cluster 72:
#  alpha
#  ypertext
#  focused
#  extents
#  file
#  files
#  fill
#  fix
#  focusable
#  for
# Cluster 73:
#  actionable
#  is
#  interactive
#  not
#  extents
#  file
#  files
#  fill
#  fix
#  focusable
# Cluster 74:
#  absolute
#  position
#  ypertext
#  focused
#  extents
#  file
#  files
#  fill
#  fix
#  focusable
# Cluster 75:
#  viewer
#  interface
#  ypertext
#  everything
#  explorer
#  extents
#  file
#  files
#  fill
#  fix
# Cluster 76:
#  lo
#  helper
#  gin
#  focused
#  extents
#  file
#  files
#  fill
#  fix
#  focusable
# Cluster 77:
#  show
#  ypertext
#  focusable
#  explorer
#  extents
#  file
#  files
#  fill
#  fix
#  focused
# Cluster 78:
#  description
#  no
#  ypertext
#  focused
#  extents
#  file
#  files
#  fill
#  fix
#  focusable
# Cluster 79:
#  offset
#  ypertext
#  extents
#  file
#  files
#  fill
#  fix
#  focusable
#  focused
#  for
# Cluster 80:
#  interface
#  focusable
#  has
#  table
#  selection
#  no
#  fill
#  explorer
#  extents
#  file
# Cluster 81:
#  defaults
#  include
#  ypertext
#  focused
#  extents
#  file
#  files
#  fill
#  fix
#  focusable
# Cluster 82:
#  gui
#  tests
#  fundamental
#  application
#  accessibility
#  focused
#  file
#  files
#  fill
#  fix
# Cluster 83:
#  column
#  ypertext
#  has
#  extents
#  file
#  files
#  fill
#  fix
#  focusable
#  focused
# Cluster 84:
#  ap
#  plication
#  explorer
#  extents
#  file
#  files
#  fill
#  fix
#  focusable
#  ypertext
# Cluster 85:
#  version
#  ypertext
#  focusable
#  explorer
#  extents
#  file
#  files
#  fill
#  fix
#  focused
# Cluster 86:
#  hyperlink
#  ypertext
#  focused
#  extents
#  file
#  files
#  fill
#  fix
#  focusable
#  for
# Cluster 87:
#  binding
#  key
#  ypertext
#  focused
#  extents
#  file
#  files
#  fill
#  fix
#  focusable
# Cluster 88:
#  uri
#  ypertext
#  except
#  extents
#  file
#  files
#  fill
#  fix
#  focusable
#  focused
# Cluster 89:
#  cell
#  selected
#  for
#  extents
#  file
#  files
#  fill
#  fix
#  focusable
#  focused
# Cluster 90:
#  val
#  ue
#  ypertext
#  focusable
#  extents
#  file
#  files
#  fill
#  fix
#  focused
# Cluster 91:
#  the
#  box
#  fill
#  color
#  of
#  highlight
#  do
#  from
#  fix
#  focusable
# Cluster 92:
#  the
#  when
#  nodes
#  selecting
#  box
#  duration
#  accessible
#  of
#  highlight
#  files
# Cluster 93:
#  dogtail
#  ypertext
#  focused
#  extents
#  file
#  files
#  fill
#  fix
#  focusable
#  for
# Cluster 94:
#  lection
#  col
#  ypertext
#  focused
#  extents
#  file
#  files
#  fill
#  fix
#  focusable
# Cluster 95:
#  table
#  ypertext
#  focused
#  extents
#  file
#  files
#  fill
#  fix
#  focusable
#  for
# Cluster 96:
#  shift
#  ypertext
#  focusable
#  explorer
#  extents
#  file
#  files
#  fill
#  fix
#  focused
# Cluster 97:
#  selection
#  ypertext
#  focusable
#  explorer
#  extents
#  file
#  files
#  fill
#  fix
#  focused
# Cluster 98:
#  implemented
#  not
#  explorer
#  file
#  files
#  fill
#  fix
#  focusable
#  focused
#  ypertext
# Cluster 99:
#  idle
#  ypertext
#  except
#  extents
#  file
#  files
#  fill
#  fix
#  focusable
#  focused
# Cluster 100:
#  currently
#  manipulating
#  console
#  interactive
#  for
#  accessible
#  selected
#  fix
#  explorer
#  extents
# Cluster 101:
#  workout
#  give
#  your
#  an
#  application
#  accessibility
#  for
#  file
#  files
#  fill
# Cluster 102:
#  ipython
#  console
#  ypertext
#  focusable
#  explorer
#  extents
#  file
#  files
#  fill
#  fix
# Cluster 103:
#  bottom
#  panel
#  for
#  file
#  files
#  fill
#  fix
#  focusable
#  focused
#  from
# Cluster 104:
#  ctrl
#  ypertext
#  focused
#  extents
#  file
#  files
#  fill
#  fix
#  focusable
#  for
# Cluster 105:
#  browser
#  api
#  explorer
#  file
#  files
#  fill
#  fix
#  focusable
#  focused
#  for
# Cluster 106:
#  mouse
#  under
#  inspect
#  accessible
#  focusable
#  explorer
#  extents
#  file
#  files
#  fill
# Cluster 107:
#  accessibles
#  quickly
#  with
#  methods
#  selecting
#  various
#  plugin
#  of
#  duration
#  edit
# Cluster 108:
#  2006
#  corporation
#  2007
#  ibm
#  copyright
#  bsd
#  accerciser
#  duration
#  does
#  fill
# Cluster 109:
#  contents
#  ypertext
#  except
#  extents
#  file
#  files
#  fill
#  fix
#  focusable
#  focused
# Cluster 110:
#  role
#  ypertext
#  focused
#  extents
#  file
#  files
#  fill
#  fix
#  focusable
#  for
# Cluster 111:
#  confirm
#  clear
#  explorer
#  extents
#  file
#  files
#  fill
#  fix
#  focusable
#  ypertext
# Cluster 112:
#  registry
#  refresh
#  ypertext
#  focusable
#  explorer
#  extents
#  file
#  files
#  fill
#  fix
# Cluster 113:
#  recorder
#  script
#  ypertext
#  explorer
#  extents
#  file
#  files
#  fill
#  fix
#  focusable
# Cluster 114:
#  credits
#  translator
#  for
#  extents
#  file
#  files
#  fill
#  fix
#  focusable
#  focused
# Cluster 115:
#  alt
#  ypertext
#  focused
#  extents
#  file
#  files
#  fill
#  fix
#  focusable
#  for
# Cluster 116:
#  info
#  ypertext
#  explorer
#  extents
#  file
#  files
#  fill
#  fix
#  focusable
#  focused
# Cluster 117:
#  minimum
#  value
#  ypertext
#  everything
#  explorer
#  extents
#  file
#  files
#  fill
#  fix
# Cluster 118:
#  new
#  view
#  ypertext
#  focusable
#  extents
#  file
#  files
#  fill
#  fix
#  focused
# Cluster 119:
#  global
#  hotkeys
#  ypertext
#  focused
#  extents
#  file
#  files
#  fill
#  fix
#  focusable
# Cluster 120:
#  except
#  has
#  explorer
#  extents
#  file
#  files
#  fill
#  fix
#  focusable
#  ypertext
# Cluster 121:
#  warn
#  ypertext
#  focusable
#  explorer
#  extents
#  file
#  files
#  fill
#  fix
#  focused
# Cluster 122:
#  level
#  ypertext
#  focused
#  explorer
#  extents
#  file
#  files
#  fill
#  fix
#  focusable
# Cluster 123:
#  site
#  web
#  except
#  explorer
#  extents
#  file
#  files
#  fill
#  fix
#  focusable
# Cluster 124:
#  maximum
#  value
#  ypertext
#  everything
#  explorer
#  extents
#  file
#  files
#  fill
#  fix
# Cluster 125:
#  than
#  more
#  one
#  widget
#  focused
#  fundamental
#  full
#  from
#  gin
#  for
# Cluster 126:
#  debug
#  ypertext
#  focused
#  extents
#  file
#  files
#  fill
#  fix
#  focusable
#  for
# Cluster 127:
#  saving
#  ypertext
#  focused
#  explorer
#  extents
#  file
#  files
#  fill
#  fix
#  focusable
# Cluster 128:
#  errors
#  plugin
#  ypertext
#  explorer
#  file
#  files
#  fill
#  fix
#  focusable
#  focused
# Cluster 129:
#  application
#  ypertext
#  explorer
#  file
#  files
#  fill
#  fix
#  focusable
#  focused
#  for
# Cluster 130:
#  alidate
#  ypertext
#  focused
#  extents
#  file
#  files
#  fill
#  fix
#  focusable
#  for
# Cluster 131:
#  state
#  without
#  has
#  focusable
#  explorer
#  extents
#  file
#  files
#  fill
#  fix
# Cluster 132:
#  help
#  ypertext
#  focused
#  extents
#  file
#  files
#  fill
#  fix
#  focusable
#  for
# Cluster 133:
#  reciprocal
#  relation
#  missing
#  for
#  focusable
#  explorer
#  extents
#  file
#  files
#  fill
# Cluster 134:
#  basic
#  ypertext
#  for
#  file
#  files
#  fill
#  fix
#  focusable
#  focused
#  from
# Cluster 135:
#  python
#  an
#  explorer
#  interactive
#  accessibility
#  focusable
#  extents
#  file
#  files
#  fill
# Cluster 136:
#  file
#  ypertext
#  has
#  explorer
#  extents
#  files
#  fill
#  fix
#  focusable
#  focused
# Cluster 137:
#  manage
#  bookmarks
#  ypertext
#  for
#  file
#  files
#  fill
#  fix
#  focusable
#  focused
# Cluster 138:
#  task
#  ypertext
#  focused
#  extents
#  file
#  files
#  fill
#  fix
#  focusable
#  for
# Cluster 139:
#  error
#  ypertext
#  except
#  extents
#  file
#  files
#  fill
#  fix
#  focusable
#  focused
# Cluster 140:
#  highlighting
#  ypertext
#  focused
#  extents
#  file
#  files
#  fill
#  fix
#  focusable
#  for
# Cluster 141:
#  native
#  ypertext
#  explorer
#  file
#  files
#  fill
#  fix
#  focusable
#  focused
#  for
# Cluster 142:
#  lost
#  will
#  be
#  script
#  current
#  the
#  ypertext
#  focused
#  extents
#  file
# Cluster 143:
#  component
#  ypertext
#  has
#  extents
#  file
#  files
#  fill
#  fix
#  focusable
#  focused
# Cluster 144:
#  ldtp
#  ypertext
#  focused
#  explorer
#  extents
#  file
#  files
#  fill
#  fix
#  focusable
# Cluster 145:
#  index
#  in
#  child
#  parent
#  match
#  does
#  not
#  focused
#  file
#  files
# Cluster 146:
#  note
#  only
#  logout
#  take
#  changes
#  effect
#  after
#  for
#  files
#  fill
# Cluster 147:
#  validates
#  application
#  accessibility
#  focused
#  extents
#  file
#  files
#  fill
#  fix
#  focusable
# Cluster 148:
#  type
#  script
#  ypertext
#  explorer
#  extents
#  file
#  files
#  fill
#  fix
#  focusable
# Cluster 149:
#  belong
#  set
#  to
#  does
#  not
#  ypertext
#  for
#  files
#  fill
#  fix
# Cluster 150:
#  the
#  license
#  notice
#  copying
#  files
#  details
#  bsd
#  see
#  new
#  and
# Cluster 151:
#  you
#  desktop
#  enable
#  to
#  do
#  want
#  applications
#  this
#  fix
#  could
# Cluster 152:
#  validating
#  except
#  explorer
#  extents
#  file
#  files
#  fill
#  fix
#  focusable
#  ypertext
# Cluster 153:
#  children
#  has
#  extents
#  file
#  files
#  fill
#  fix
#  focusable
#  focused
#  ypertext
# Cluster 154:
#  top
#  panel
#  ypertext
#  focused
#  extents
#  file
#  files
#  fill
#  fix
#  focusable
# Cluster 155:
#  creates
#  scripts
#  style
#  dogtail
#  ypertext
#  explorer
#  extents
#  file
#  files
#  fill
# Cluster 156:
#  text
#  has
#  interface
#  no
#  focusable
#  extents
#  file
#  files
#  fill
#  fix
# Cluster 157:
#  label
#  missing
#  or
#  name
#  ypertext
#  focusable
#  extents
#  file
#  files
#  fill
# Cluster 158:
#  current
#  value
#  focused
#  explorer
#  extents
#  file
#  files
#  fill
#  fix
#  focusable
# Cluster 159:
#  actionable
#  focusable
#  is
#  selectable
#  or
#  not
#  focused
#  extents
#  file
#  files
# Cluster 160:
#  all
#  refresh
#  ypertext
#  focused
#  extents
#  file
#  files
#  fill
#  fix
#  focusable
# Cluster 161:
#  no
#  view
#  ypertext
#  focusable
#  extents
#  file
#  files
#  fill
#  fix
#  focused
# Cluster 162:
#  rows
#  has
#  explorer
#  extents
#  file
#  files
#  fill
#  fix
#  focusable
#  focused
# Cluster 163:
#  accessible
#  ypertext
#  for
#  extents
#  file
#  files
#  fill
#  fix
#  focusable
#  focused
# Cluster 164:
#  key
#  ypertext
#  focusable
#  explorer
#  extents
#  file
#  files
#  fill
#  fix
#  focused
# Cluster 165:
#  the
#  pluginview
#  bottom
#  layout
#  panel
#  for
#  fundamental
#  full
#  from
#  explorer
# Cluster 166:
#  bookmarks
#  ypertext
#  for
#  file
#  files
#  fill
#  fix
#  focusable
#  focused
#  from
# Cluster 167:
#  full
#  name
#  ypertext
#  focused
#  file
#  files
#  fill
#  fix
#  focusable
#  for
# Cluster 168:
#  plugins
#  ypertext
#  has
#  extents
#  file
#  files
#  fill
#  fix
#  focusable
#  focused
# Cluster 169:
#  bookmark
#  accessible
#  selected
#  ypertext
#  extents
#  file
#  files
#  fill
#  fix
#  focusable
# Cluster 170:
#  states
#  ypertext
#  except
#  extents
#  file
#  files
#  fill
#  fix
#  focusable
#  focused
# Cluster 171:
#  count
#  child
#  ypertext
#  focused
#  extents
#  file
#  files
#  fill
#  fix
#  focusable
# Cluster 172:
#  editable
#  except
#  extents
#  file
#  files
#  fill
#  fix
#  focusable
#  focused
#  ypertext
# Cluster 173:
#  edit
#  ypertext
#  focused
#  extents
#  file
#  files
#  fill
#  fix
#  focusable
#  for
# Cluster 174:
#  unknown
#  ypertext
#  except
#  extents
#  file
#  files
#  fill
#  fix
#  focusable
#  focused
# Cluster 175:
#  columns
#  selected
#  focused
#  extents
#  file
#  files
#  fill
#  fix
#  focusable
#  ypertext
# Cluster 176:
#  relations
#  ypertext
#  focused
#  extents
#  file
#  files
#  fill
#  fix
#  focusable
#  for
# Cluster 177:
#  available
#  pluginviews
#  new
#  ypertext
#  file
#  files
#  fill
#  fix
#  focusable
#  focused
# Cluster 178:
#  summary
#  except
#  extents
#  file
#  files
#  fill
#  fix
#  focusable
#  focused
#  ypertext
# Cluster 179:
#  caption
#  ypertext
#  focused
#  extents
#  file
#  files
#  fill
#  fix
#  focusable
#  for
# Cluster 180:
#  index
#  num2
#  num1
#  parent
#  rolename
#  match
#  column
#  row
#  does
#  and
# Cluster 181:
#  preferences
#  has
#  explorer
#  extents
#  file
#  files
#  fill
#  fix
#  focusable
#  ypertext
# Cluster 182:
#  node
#  refresh
#  ypertext
#  focused
#  extents
#  file
#  files
#  fill
#  fix
#  focusable
# Cluster 183:
#  border
#  color
#  highlight
#  ypertext
#  focused
#  file
#  files
#  fill
#  fix
#  focusable
# Cluster 184:
#  attributes
#  ypertext
#  explorer
#  file
#  files
#  fill
#  fix
#  focusable
#  focused
#  for
# Cluster 185:
#  fill
#  color
#  highlight
#  ypertext
#  focused
#  file
#  files
#  fix
#  focusable
#  for
# Cluster 186:
#  the
#  opacity
#  border
#  and
#  color
#  of
#  highlight
#  focused
#  files
#  fill
# Cluster 187:
#  accerciser
#  ypertext
#  for
#  extents
#  file
#  files
#  fill
#  fix
#  focusable
#  focused
# Cluster 188:
#  single
#  layout
#  view
#  ypertext
#  fix
#  explorer
#  extents
#  file
#  files
#  fill
# Cluster 189:
#  the
#  box
#  border
#  color
#  of
#  highlight
#  document
#  from
#  fix
#  focusable
# Cluster 190:
#  the
#  bottom
#  default
#  layout
#  panel
#  plugin
#  for
#  fundamental
#  full
#  from
# Cluster 191:
#  the
#  top
#  layout
#  panel
#  for
#  focusable
#  extents
#  file
#  files
#  fill
# Cluster 192:
#  the
#  pluginview
#  top
#  layout
#  panel
#  for
#  fundamental
#  full
#  from
#  focused
# Cluster 193:
#  the
#  bottom
#  layout
#  panel
#  for
#  file
#  files
#  fill
#  fix
#  focusable
# Cluster 194:
#  node
#  children
#  refresh
#  selected
#  focused
#  extents
#  file
#  files
#  fill
#  fix
# Cluster 195:
#  entry
#  last
#  event
#  highlight
#  ypertext
#  focusable
#  extents
#  file
#  files
#  fill
# Cluster 196:
#  you
#  desktop
#  enable
#  to
#  do
#  want
#  applications
#  this
#  fix
#  could
# Cluster 197:
#  entry
#  last
#  event
#  highlight
#  ypertext
#  focusable
#  extents
#  file
#  files
#  fill
# Cluster 198:
#  node
#  children
#  refresh
#  selected
#  focused
#  extents
#  file
#  files
#  fill
#  fix
# Cluster 199:
#  entry
#  last
#  event
#  highlight
#  ypertext
#  focusable
#  extents
#  file
#  files
#  fill
#
#
# Prediction
# [105]
# [73]
# /usr/local/lib/python3.6/dist-packages/sklearn/cluster/k_means_.py:969: ConvergenceWarning: Number of distinct clusters (194) found smaller than n_clusters (200). Possibly due to duplicate points in X.
#   return_n_iter=True)
