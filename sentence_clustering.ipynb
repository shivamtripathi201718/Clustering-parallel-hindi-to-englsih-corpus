# %% [markdown]
# <a href="https://colab.research.google.com/github/shivamtripathi201718/Clustering-parallel-hindi-to-englsih-corpus/blob/master/sentence_clustering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
fp = open("hi.txt", "r+")
documents = fp.readlines()[1:-1]
print(documents)
# Out:
# ['एक्सेर्साइसर पहुंचनीयता अन्वेषक\n', 'निचले पटल के लिए डिफोल्ट प्लग-इन खाका\n', 'ऊपरी पटल के लिए डिफोल्ट प्लग-इन खाका\n', 'उन प्लग-इनों की सूची जिन्हें डिफोल्ट रूप से निष्क्रिय किया गया है\n', 'अवधि को हाइलाइट रकें\n', 'पहुंचनीय आसंधि (नोड) को चुनते समय हाइलाइट बक्से की अवधि\n', 'सीमांत (बोर्डर) के रंग को हाइलाइट करें\n', 'हाइलाइट किए गए सीमांत का रंग और अपारदर्शिता। \n', 'भराई के रंग को हाइलाइट करें\n', 'हाइलाइट किया गया भराई का रंग और पारदर्शिता। \n', 'एपीआई विचरक\n', 'इस समय जिसे प्राप्त किया गया हो, उसकी विभिन्न विधियों (मेथड) में विचरण करें\n', 'निजी गुणों को छिपाएं\n', 'विधि\n', 'गुणधर्म\n', 'मान\n', 'आईपाइथन कन्सोल\n', 'इस समय चुने गए एक्सेसेबेल से काम लेने के लिए अंतर्क्रियात्मक कन्सोल\n', 'घटना मानिटर\n', 'घटनाओं को मानिटर करें (_ M) \n', 'चुनाव को हटाएं (C _) \n', 'सभी\n', 'चुने गए अनुप्रयोग\n', 'चुने गए एक्सेसेबेल\n', 'स्रोत\n', 'घटना मानिटर\n', 'चुने गए प्रकारों और स्रोतों से घटनाएं जैसे-जैसे घटित होती हैं, उन्हें दर्शाता है\n', 'अंतिम प्रविष्ट घटना को हाइलाइट करो\n', 'घटना रेकोर्डिंग शुरू करो/रोको\n', 'घटना रोजनामचा मिटाओ\n', 'कोई विवरण नहीं\n', 'वर्णन\n', 'दिखाएं\n', 'पहुंचनीय\n', 'कार्रवाई संपन्न करें\n', 'कार्रवाई (_ o) \n', 'आईडी\n', 'औजार बक्सा\n', 'संस्करण\n', 'अनुप्रयोग\n', 'संग्रह\n', '0, 0\n', 'सापेक्ष स्थिति\n', 'आकार\n', 'विडजेट\n', 'स्तर\n', 'एमडीआई-जेड-क्रम\n', 'अल्फा\n', 'निरपेक्ष स्थिति\n', 'घटक\n', 'डेस्कटोप\n', 'स्थान-विशिष्टः\n', 'प्रलेख\n', 'हाइपरकड़ी\n', 'हाइपरपाठ\n', 'स्थिति\n', 'वर्णन\n', 'स्थान-विशिष्ट\n', 'छवि (_ I) \n', 'प्रवेश सहायक\n', 'सभी चुनें\n', 'चयन (_ S) \n', 'प्रवाहित करनेयोग्य विषयवस्तु\n', 'चुने गए स्तंभ\n', 'चुनी गई पंक्तियां\n', 'स्तंभ\n', 'पंक्तियां\n', '& lt; bgt; सारणी सूचनाlt;/bgt; \n', 'नाम (x, y) \n', 'शीर्षकः\n', 'विस्तारः\n', 'पंक्ति\n', 'स्तंभ\n', '& lt; bgt; चुनी गई कोशिकाlt;/bgt; \n', 'सारणी (_ T) \n', 'ओफसेट\n', 'डिफोल्टों को शामिल करें\n', 'पाठ (_ x) \n', 'मौजूदा मान\n', 'न्यूनतम वृद्धि\n', 'अधिकतम मान\n', 'न्यूनतम मान\n', 'मान\n', 'अंतराफलक दर्शक\n', 'अंतराफलक के विभिन्न गुणों को देखने देता है\n', '(क्रियान्वित नहीं हुआ है) \n', 'नाम\n', 'यूआरआई\n', 'प्रारंभ\n', 'अंत\n', 'बहुत अधिक चयनीय शिशु हैं\n', 'तेज चुनाव\n', 'प्लग-इन जिसमें हैं एक्सेसेबेलों को तेजी से चुनने के लिए कई विधियां\n', 'अंतिम बार फोकस किए गए एक्सेसेबल को जांचें\n', 'माउस के अधीन जो एक्सेसेबल है, उसे जांचें\n', 'वतनी\n', 'श्वानपुच्छ\n', 'एलडीटीपी\n', 'लिपि प्रकार\n', 'लिपि रेकोर्डर\n', 'श्वानपुच्छ शैली की लिपियां निर्मित करता है\n', 'वर्तमान लिपि (स्क्रिप्ट) खो जाएगी। \n', 'मिटाने की पुष्टि करें\n', 'स्कीमाः\n', 'सत्यापन\n', 'खाली\n', 'कोई विवरण नहीं\n', 'एटी-एसपीआई सत्यापक\n', 'अनुप्रयोग की पहुंचनीयता का सत्यापन करता है\n', 'स्तर\n', 'भूमिका\n', 'सहेज रहे हैं\n', 'पुष्टि कर रहे हैं\n', 'अपवाद\n', 'त्रुटि\n', 'चेतावनी\n', 'सूचना\n', 'दोषमुक्त करें\n', 'मूल\n', 'मूलभूत जीयूआई अनुप्रयोग पहुंचनीयता का परीक्षण करता है\n', '% s जिस पर कार्रवाई हो सकती है, वह न तो फोकस करने योग्य है न ही चयनीय\n', 'अंतर्क्रियात्मक% s कार्रवाई करने योग्य नहीं है\n', 'एक से अधिक विडजेट फोकस में है\n', '% s का कोई पाठ अंतराफलक नहीं है\n', 'अभिभावक में% s सूची शिशु सूची सेमेल नहीं खाती\n', '% s संबंध के लिए अन्योन्य गायब है\n', '% s गायब नाम या सूचक\n', 'फोकस योग्य% s में सारणी अंतराफलक है, कोई चयनीय अंतराफलक नहीं हैbutton has focused state without focusable state\n', '% s में% s स्थिति है, पर उसके साथ% s स्थिति नहीं है\n', '% s किसी समुच्चय का सदस्य नहीं है\n', '% (rolename) s सूची% (num) d पंक्ति और स्तंभ से मेल नहीं खातेparent indexrow and column index\n', '% (rolename) s अभिभावक सूची% (num1) d पंक्ति और स्तंभ सूची% (num2) d से मेल नहीं खाते\n', '% s का कोई नाम या विवरण नहीं\n', 'पसंद (_ P)... \n', 'विषय सूची (_ C) \n', 'एक्सेरसाइसर आपके डेस्कटोप में मौजूद अनुप्रयोग नहीं देख पाया। इस समस्या के समाधान के लिए आपको डेस्कटोप पहुंचनीयता को सक्रिय करना होगा। क्या आप इसे सक्रिय करना चाहते हैं? \n', 'टिप्पणीः परिवर्तन सत्रांत (लोगआउट) के बाद ही प्रभाव में आएंगे। \n', 'शिशु\n', 'पंजी ताजा करें (_ R) \n', 'सभी को ताजा करें\n', 'आसंधि (नोड) को ताजा करें (_ N) \n', 'चुनी गई आसंधियों (नोड) के शिशुओं को ताजा करें\n', 'घटक\n', 'कार्य ...

# %%
import nltk

nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
    import collections
    from nltk import word_tokenize
    from nltk.corpus import stopwords
    from nltk.stem import PorterStemmer
    from sklearn.cluster import KMeans
    from sklearn.feature_extraction.text import TfidfVectorizer
    from pprint import pprint


    def word_tokenizer(text):
            #tokenizes and stems the text
            tokens = word_tokenize(text)
            stemmer = PorterStemmer()
            tokens = [stemmer.stem(t) for t in tokens if t not in stopwords.words('english')]
            return tokens


    def cluster_sentences(sentences, nb_of_clusters=5):
            tfidf_vectorizer = TfidfVectorizer(tokenizer=word_tokenizer,
                                            stop_words=stopwords.words('english'),
                                            max_df=0.9,
                                            min_df=0.1,
                                            lowercase=True)
            #builds a tf-idf matrix for the sentences
            tfidf_matrix = tfidf_vectorizer.fit_transform(sentences)
            kmeans = KMeans(n_clusters=nb_of_clusters)
            kmeans.fit(tfidf_matrix)
            clusters = collections.defaultdict(list)
            for i, label in enumerate(kmeans.labels_):
                    clusters[label].append(i)
            return dict(clusters)


    if __name__ == "__main__":
#            
            nclusters= 4
            clusters = cluster_sentences(documents, nclusters)
            for cluster in range(nclusters):
                    print("cluster ",cluster,":")
                    for i,sentence in enumerate(clusters[cluster]):
                            print("\tsentence ",i,": ",documents[sentence])
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/feature_extraction/text.py:300: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ["'d", "'ll", "'re", "'s", "'ve", 'could', 'might', 'must', "n't", 'need', 'sha', 'wo', 'would'] not in stop_words.
#   'stop_words.' % sorted(inconsistent))
# cluster  0 :
# 	sentence  0 :  एक्सेर्साइसर पहुंचनीयता अन्वेषक
#
# 	sentence  1 :  निचले पटल के लिए डिफोल्ट प्लग-इन खाका
#
# 	sentence  2 :  ऊपरी पटल के लिए डिफोल्ट प्लग-इन खाका
#
# 	sentence  3 :  उन प्लग-इनों की सूची जिन्हें डिफोल्ट रूप से निष्क्रिय किया गया है
#
# 	sentence  4 :  हाइलाइट किए गए सीमांत का रंग और अपारदर्शिता।
#
# 	sentence  5 :  हाइलाइट किया गया भराई का रंग और पारदर्शिता।
#
# 	sentence  6 :  एपीआई विचरक
#
# 	sentence  7 :  विधि
#
# 	sentence  8 :  गुणधर्म
#
# 	sentence  9 :  मान
#
# 	sentence  10 :  आईपाइथन कन्सोल
#
# 	sentence  11 :  इस समय चुने गए एक्सेसेबेल से काम लेने के लिए अंतर्क्रियात्मक कन्सोल
#
# 	sentence  12 :  घटना मानिटर
#
# 	sentence  13 :  सभी
#
# 	sentence  14 :  चुने गए अनुप्रयोग
#
# 	sentence  15 :  चुने गए एक्सेसेबेल
#
# 	sentence  16 :  स्रोत
#
# 	sentence  17 :  घटना मानिटर
#
# 	sentence  18 :  चुने गए प्रकारों और स्रोतों से घटनाएं जैसे-जैसे घटित होती हैं, उन्हें दर्शाता है
#
# 	sentence  19 :  घटना रेकोर्डिंग शुरू करो/रोको
#
# 	sentence  20 :  घटना रोजनामचा मिटाओ
#
# 	sentence  21 :  कोई विवरण नहीं
#
# 	sentence  22 :  वर्णन
#
# 	sentence  23 :  दिखाएं
#
# 	sentence  24 :  पहुंचनीय
#
# 	sentence  25 :  कार्रवाई संपन्न करें
#
# 	sentence  26 :  आईडी
#
# 	sentence  27 :  औजार बक्सा
#
# 	sentence  28 :  संस्करण
#
# 	sentence  29 :  अनुप्रयोग
#
# 	sentence  30 :  संग्रह
#
# 	sentence  31 :  0, 0
#
# 	sentence  32 :  सापेक्ष स्थिति
#
# 	sentence  33 :  आकार
#
# 	sentence  34 :  विडजेट
#
# 	sentence  35 :  स्तर
#
# 	sentence  36 :  एमडीआई-जेड-क्रम
#
# 	sentence  37 :  अल्फा
#
# 	sentence  38 :  निरपेक्ष स्थिति
#
# 	sentence  39 :  घटक
#
# 	sentence  40 :  डेस्कटोप
#
# 	sentence  41 :  स्थान-विशिष्टः
#
# 	sentence  42 :  प्रलेख
#
# 	sentence  43 :  हाइपरकड़ी
#
# 	sentence  44 :  हाइपरपाठ
#
# 	sentence  45 :  स्थिति
#
# 	sentence  46 :  वर्णन
#
# 	sentence  47 :  स्थान-विशिष्ट
#
# 	sentence  48 :  प्रवेश सहायक
#
# 	sentence  49 :  सभी चुनें
#
# 	sentence  50 :  प्रवाहित करनेयोग्य विषयवस्तु
#
# 	sentence  51 :  चुने गए स्तंभ
#
# 	sentence  52 :  चुनी गई पंक्तियां
#
# 	sentence  53 :  स्तंभ
#
# 	sentence  54 :  पंक्तियां
#
# 	sentence  55 :  & lt; bgt; सारणी सूचनाlt;/bgt;
#
# 	sentence  56 :  शीर्षकः
#
# 	sentence  57 :  विस्तारः
#
# 	sentence  58 :  पंक्ति
#
# 	sentence  59 :  स्तंभ
#
# 	sentence  60 :  & lt; bgt; चुनी गई कोशिकाlt;/bgt;
#
# 	sentence  61 :  ओफसेट
#
# 	sentence  62 :  मौजूदा मान
#
# 	sentence  63 :  न्यूनतम वृद्धि
#
# 	sentence  64 :  अधिकतम मान
#
# 	sentence  65 :  न्यूनतम मान
#
# 	sentence  66 :  मान
#
# 	sentence  67 :  अंतराफलक दर्शक
#
# 	sentence  68 :  नाम
#
# 	sentence  69 :  यूआरआई
#
# 	sentence  70 :  प्रारंभ
#
# 	sentence  71 :  अंत
#
# 	sentence  72 :  बहुत अधिक चयनीय शिशु हैं
#
# 	sentence  73 :  तेज चुनाव
#
# 	sentence  74 :  माउस के अधीन जो एक्सेसेबल है, उसे जांचें
#
# 	sentence  75 :  वतनी
#
# 	sentence  76 :  श्वानपुच्छ
#
# 	sentence  77 :  एलडीटीपी
#
# 	sentence  78 :  लिपि प्रकार
#
# 	sentence  79 :  लिपि रेकोर्डर
#
# 	sentence  80 :  श्वानपुच्छ शैली की लिपियां निर्मित करता है
#
# 	sentence  81 :  मिटाने की पुष्टि करें
#
# 	sentence  82 :  स्कीमाः
#
# 	sentence  83 :  सत्यापन
#
# 	sentence  84 :  खाली
#
# 	sentence  85 :  कोई विवरण नहीं
#
# 	sentence  86 :  एटी-एसपीआई सत्यापक
#
# 	sentence  87 :  अनुप्रयोग की पहुंचनीयता का सत्यापन करता है
#
# 	sentence  88 :  स्तर
#
# 	sentence  89 :  भूमिका
#
# 	sentence  90 :  सहेज रहे हैं
#
# 	sentence  91 :  पुष्टि कर रहे हैं
#
# 	sentence  92 :  अपवाद
#
# 	sentence  93 :  त्रुटि
#
# 	sentence  94 :  चेतावनी
#
# 	sentence  95 :  सूचना
#
# 	sentence  96 :  दोषमुक्त करें
#
# 	sentence  97 :  मूल
#
# 	sentence  98 :  मूलभूत जीयूआई अनुप्रयोग पहुंचनीयता का परीक्षण करता है
#
# 	sentence  99 :  % s जिस पर कार्रवाई हो सकती है, वह न तो फोकस करने योग्य है न ही चयनीय
#
# 	sentence  100 :  अंतर्क्रियात्मक% s कार्रवाई करने योग्य नहीं है
#
# 	sentence  101 :  एक से अधिक विडजेट फोकस में है
#
# 	sentence  102 :  % s का कोई पाठ अंतराफलक नहीं है
#
# 	sentence  103 :  अभिभावक में% s सूची शिशु सूची सेमेल नहीं खाती
#
# 	sentence  104 :  % s संबंध के लिए अन्योन्य गायब है
#
# 	sentence  105 :  % s गायब नाम या सूचक
#
# 	sentence  106 :  फोकस योग्य% s में सारणी अंतराफलक है, कोई चयनीय अंतराफलक नहीं हैbutton has focused state without focusable state
#
# 	sentence  107 :  % s में% s स्थिति है, पर उसके साथ% s स्थिति नहीं है
#
# 	sentence  108 :  % s किसी समुच्चय का सदस्य नहीं है
#
# 	sentence  109 :  % s का कोई नाम या विवरण नहीं
#
# 	sentence  110 :  शिशु
#
# 	sentence  111 :  घटक
#
# 	sentence  112 :  कार्य
#
# 	sentence  113 :  कुंजी
#
# 	sentence  114 :  आल्ट
#
# 	sentence  115 :  कंट्रोल
#
# 	sentence  116 :  शिफ्ट
#
# 	sentence  117 :  ऊपरी पटल
#
# 	sentence  118 :  निचला पटल
#
# 	sentence  119 :  एक्सेर्साइसर पसंद
#
# 	sentence  120 :  प्लगइन्स
#
# 	sentence  121 :  सार्वत्रिक फटाफट कुंजियां
#
# 	sentence  122 :  हाइलाइटन
#
# 	sentence  123 :  हाइलाइट अवधिः
#
# 	sentence  124 :  सीमांत रंगः
#
# 	sentence  125 :  हाइलाइट बक्से का सीमांत रंग
#
# 	sentence  126 :  भराई का रंगः
#
# 	sentence  127 :  हाइलाइट बक्से का भराई रंग
#
# 	sentence  128 :  एक अंतर्क्रियात्मक पाइथन पहुंचनीयता अन्वेषक
#
# 	sentence  129 :  नया बीएसडी लाइसेन्स विवरण के लिए देखिए प्रतिलिपीकरण और सूचना फाइलें
#
# 	sentence  130 :  जाल स्थल
#
# 	sentence  131 :  शीर्षक
#
# 	sentence  132 :  अनुप्रयोग
#
# 	sentence  133 :  पथ
#
# 	sentence  134 :  पुस्तक-चिह्न जोड़ें...
#
# 	sentence  135 :  शीर्षकः
#
# 	sentence  136 :  अनुप्रयोगः
#
# 	sentence  137 :  पथः
#
# 	sentence  138 :  प्लग-इन त्रुटियां
#
# 	sentence  139 :  दृश्य
#
# 	sentence  140 :  कोई दृश्य नहीं है
#
# 	sentence  141 :  एकल प्लग-इन दृश्य
#
# 	sentence  142 :  प्लग-इन दृश्य
#
# 	sentence  143 :  नया दृश्य...
#
# 	sentence  144 :  नया दृश्य...
#
# 	sentence  145 :  संपादित करें
#
# 	sentence  146 :  मदद
#
# 	sentence  147 :  पूरा नाम
#
# 	sentence  148 :  कुंजी बंधन
#
# 	sentence  149 :  विषय प्रकार
#
# 	sentence  150 :  एक्सेर्साइसर पहुंचनीयता अन्वेषक
#
# 	sentence  151 :  निचले पटल के लिए डिफोल्ट प्लग-इन खाका
#
# 	sentence  152 :  ऊपरी पटल के लिए डिफोल्ट प्लग-इन खाका
#
# 	sentence  153 :  उन प्लग-इनों की सूची जिन्हें डिफोल्ट रूप से निष्क्रिय किया गया है
#
# 	sentence  154 :  हाइलाइट किए गए सीमांत का रंग और अपारदर्शिता।
#
# 	sentence  155 :  हाइलाइट किया गया भराई का रंग और पारदर्शिता।
#
# 	sentence  156 :  एपीआई विचरक
#
# 	sentence  157 :  विधि
#
# 	sentence  158 :  गुणधर्म
#
# 	sentence  159 :  मान
#
# 	sentence  160 :  आईपाइथन कन्सोल
#
# 	sentence  161 :  इस समय चुने गए एक्सेसेबेल से काम लेने के लिए अंतर्क्रियात्मक कन्सोल
#
# 	sentence  162 :  घटना मानिटर
#
# 	sentence  163 :  सभी
#
# 	sentence  164 :  चुने गए अनुप्रयोग
#
# 	sentence  165 :  चुने गए एक्सेसेबेल
#
# 	sentence  166 :  स्रोत
#
# 	sentence  167 :  घटना मानिटर
#
# 	sentence  168 :  चुने गए प्रकारों और स्रोतों से घटनाएं जैसे-जैसे घटित होती हैं, उन्हें दर्शाता है
#
# 	sentence  169 :  घटना रेकोर्डिंग शुरू करो/रोको
#
# 	sentence  170 :  घटना रोजनामचा मिटाओ
#
# 	sentence  171 :  कोई विवरण नहीं
#
# 	sentence  172 :  वर्णन
#
# 	sentence  173 :  दिखाएं
#
# 	sentence  174 :  पहुंचनीय
#
# 	sentence  175 :  कार्रवाई संपन्न करें
#
# 	sentence  176 :  आईडी
#
# 	sentence  177 :  औजार बक्सा
#
# 	sentence  178 :  संस्करण
#
# 	sentence  179 :  अनुप्रयोग
#
# 	sentence  180 :  संग्रह
#
# 	sentence  181 :  0, 0
#
# 	sentence  182 :  सापेक्ष स्थिति
#
# 	sentence  183 :  आकार
#
# 	sentence  184 :  विडजेट
#
# 	sentence  185 :  स्तर
#
# 	sentence  186 :  एमडीआई-जेड-क्रम
#
# 	sentence  187 :  अल्फा
#
# 	sentence  188 :  निरपेक्ष स्थिति
#
# 	sentence  189 :  घटक
#
# 	sentence  190 :  डेस्कटोप
#
# 	sentence  191 :  स्थान-विशिष्टः
#
# 	sentence  192 :  प्रलेख
#
# 	sentence  193 :  हाइपरकड़ी
#
# 	sentence  194 :  हाइपरपाठ
#
# 	sentence  195 :  स्थिति
#
# 	sentence  196 :  वर्णन
#
# 	sentence  197 :  स्थान-विशिष्ट
#
# 	sentence  198 :  प्रवेश सहायक
#
# 	sentence  199 :  सभी चुनें
#
# 	sentence  200 :  प्रवाहित करनेयोग्य विषयवस्तु
#
# 	sentence  201 :  चुने गए स्तंभ
#
# 	sentence  202 :  चुनी गई पंक्तियां
#
# 	sentence  203 :  स्तंभ
#
# 	sentence  204 :  पंक्तियां
#
# 	sentence  205 :  & lt; bgt; सारणी सूचनाlt;/bgt;
#
# 	sentence  206 :  शीर्षकः
#
# 	sentence  207 :  विस्तारः
#
# 	sentence  208 :  पंक्ति
#
# 	sentence  209 :  स्तंभ
#
# 	sentence  210 :  & lt; bgt; चुनी गई कोशिकाlt;/bgt;
#
# 	sentence  211 :  ओफसेट
#
# 	sentence  212 :  मौजूदा मान
#
# 	sentence  213 :  न्यूनतम वृद्धि
#
# 	sentence  214 :  अधिकतम मान
#
# 	sentence  215 :  न्यूनतम मान
#
# 	sentence  216 :  मान
#
# 	sentence  217 :  अंतराफलक दर्शक
#
# 	sentence  218 :  नाम
#
# 	sentence  219 :  यूआरआई
#
# 	sentence  220 :  प्रारंभ
#
# 	sentence  221 :  अंत
#
# 	sentence  222 :  बहुत अधिक चयनीय शिशु हैं
#
# 	sentence  223 :  तेज चुनाव
#
# 	sentence  224 :  माउस के अधीन जो एक्सेसेबल है, उसे जांचें
#
# 	sentence  225 :  वतनी
#
# 	sentence  226 :  श्वानपुच्छ
#
# 	sentence  227 :  एलडीटीपी
#
# 	sentence  228 :  लिपि प्रकार
#
# 	sentence  229 :  लिपि रेकोर्डर
#
# 	sentence  230 :  श्वानपुच्छ शैली की लिपियां निर्मित करता है
#
# 	sentence  231 :  मिटाने की पुष्टि करें
#
# 	sentence  232 :  स्कीमाः
#
# 	sentence  233 :  सत्यापन
#
# 	sentence  234 :  खाली
#
# 	sentence  235 :  कोई विवरण नहीं
#
# 	sentence  236 :  एटी-एसपीआई सत्यापक
#
# 	sentence  237 :  अनुप्रयोग की पहुंचनीयता का सत्यापन करता है
#
# 	sentence  238 :  स्तर
#
# 	sentence  239 :  भूमिका
#
# 	sentence  240 :  सहेज रहे हैं
#
# 	sentence  241 :  पुष्टि कर रहे हैं
#
# 	sentence  242 :  अपवाद
#
# 	sentence  243 :  त्रुटि
#
# 	sentence  244 :  चेतावनी
#
# 	sentence  245 :  सूचना
#
# 	sentence  246 :  दोषमुक्त करें
#
# 	sentence  247 :  मूल
#
# 	sentence  248 :  मूलभूत जीयूआई अनुप्रयोग पहुंचनीयता का परीक्षण करता है
#
# 	sentence  249 :  % s जिस पर कार्रवाई हो सकती है, वह न तो फोकस करने योग्य है न ही चयनीय
#
# 	sentence  250 :  अंतर्क्रियात्मक% s कार्रवाई करने योग्य नहीं है
#
# 	sentence  251 :  एक से अधिक विडजेट फोकस में है
#
# 	sentence  252 :  % s का कोई पाठ अंतराफलक नहीं है
#
# 	sentence  253 :  अभिभावक में% s सूची शिशु सूची सेमेल नहीं खाती
#
# 	sentence  254 :  % s संबंध के लिए अन्योन्य गायब है
#
# 	sentence  255 :  % s गायब नाम या सूचक
#
# 	sentence  256 :  फोकस योग्य% s में सारणी अंतराफलक है, कोई चयनीय अंतराफलक नहीं हैbutton has focused state without focusable state
#
# 	sentence  257 :  % s में% s स्थिति है, पर उसके साथ% s स्थिति नहीं है
#
# 	sentence  258 :  % s किसी समुच्चय का सदस्य नहीं है
#
# 	sentence  259 :  % s का कोई नाम या विवरण नहीं
#
# 	sentence  260 :  शिशु
#
# 	sentence  261 :  घटक
#
# 	sentence  262 :  कार्य
#
# 	sentence  263 :  कुंजी
#
# 	sentence  264 :  आल्ट
#
# 	sentence  265 :  कंट्रोल
#
# 	sentence  266 :  शिफ्ट
#
# 	sentence  267 :  ऊपरी पटल
#
# 	sentence  268 :  निचला पटल
#
# 	sentence  269 :  एक्सेर्साइसर पसंद
#
# 	sentence  270 :  प्लगइन्स
#
# 	sentence  271 :  सार्वत्रिक फटाफट कुंजियां
#
# 	sentence  272 :  हाइलाइटन
#
# 	sentence  273 :  हाइलाइट अवधिः
#
# 	sentence  274 :  सीमांत रंगः
#
# 	sentence  275 :  हाइलाइट बक्से का सीमांत रंग
#
# 	sentence  276 :  भराई का रंगः
#
# 	sentence  277 :  हाइलाइट बक्से का भराई रंग
#
# 	sentence  278 :  एक अंतर्क्रियात्मक पाइथन पहुंचनीयता अन्वेषक
#
# 	sentence  279 :  नया बीएसडी लाइसेन्स विवरण के लिए देखिए प्रतिलिपीकरण और सूचना फाइलें
#
# 	sentence  280 :  जाल स्थल
#
# 	sentence  281 :  शीर्षक
#
# 	sentence  282 :  अनुप्रयोग
#
# 	sentence  283 :  पथ
#
# 	sentence  284 :  पुस्तक-चिह्न जोड़ें...
#
# 	sentence  285 :  शीर्षकः
#
# 	sentence  286 :  अनुप्रयोगः
#
# 	sentence  287 :  पथः
#
# 	sentence  288 :  प्लग-इन त्रुटियां
#
# 	sentence  289 :  दृश्य
#
# 	sentence  290 :  कोई दृश्य नहीं है
#
# 	sentence  291 :  एकल प्लग-इन दृश्य
#
# 	sentence  292 :  प्लग-इन दृश्य
#
# 	sentence  293 :  नया दृश्य...
#
# 	sentence  294 :  नया दृश्य...
#
# 	sentence  295 :  संपादित करें
#
# 	sentence  296 :  मदद
#
# 	sentence  297 :  पूरा नाम
#
# 	sentence  298 :  कुंजी बंधन
#
# 	sentence  299 :  विषय प्रकार
#
# 	sentence  300 :  एक्सेर्साइसर
#
# 	sentence  301 :  एक्सेर्साइसर पहुंचनीयता अन्वेषक
#
# 	sentence  302 :  उन प्लग-इनों की सूची जिन्हें डिफोल्ट रूप से निष्क्रिय किया गया है
#
# 	sentence  303 :  उन प्लग-इनों की सूची जिन्हें डिफोल्ट रूप से निष्क्रिय किया गया है
#
# 	sentence  304 :  हाइलाइट किया गया भराई का रंग और पारदर्शिता।
#
# 	sentence  305 :  हाइलाइट किए गए सीमांत का रंग और अपारदर्शिता।
#
# 	sentence  306 :  नीचे के पैनल के लिए लेआउट
#
# 	sentence  307 :  नीचे पैनल pluginview के लिए लेआउट.
#
# 	sentence  308 :  ऊपरी पटल के लिए खाका
#
# 	sentence  309 :  शीर्ष पैनल pluginview के लिए लेआउट.
#
# 	sentence  310 :  एकल लेआउट दृश्य
#
# 	sentence  311 :  नई pluginviews उपलब्ध है
#
# 	sentence  312 :  ऊपरी पटल के लिए डिफोल्ट प्लग-इन खाका.
#
# 	sentence  313 :  एपीआई विचरक
#
# 	sentence  314 :  विधि
#
# 	sentence  315 :  गुणधर्म
#
# 	sentence  316 :  मान
#
# 	sentence  317 :  आईपाइथन कन्सोल
#
# 	sentence  318 :  इस समय चुने गए एक्सेसेबेल से काम लेने के लिए अंतर्क्रियात्मक कन्सोल
#
# 	sentence  319 :  घटना मानिटर
#
# 	sentence  320 :  सभी
#
# 	sentence  321 :  चुने गए अनुप्रयोग
#
# 	sentence  322 :  चुने गए एक्सेसेबेल
#
# 	sentence  323 :  स्रोत
#
# 	sentence  324 :  घटना मानिटर
#
# 	sentence  325 :  चुने गए प्रकारों और स्रोतों से घटनाएं जैसे-जैसे घटित होती हैं, उन्हें दर्शाता है
#
# 	sentence  326 :  घटना रेकोर्डिंग शुरू करो/रोको
#
# 	sentence  327 :  घटना रोजनामचा मिटाओ
#
# 	sentence  328 :  बाल गणना
#
# 	sentence  329 :  वर्णन
#
# 	sentence  330 :  राज्य
#
# 	sentence  331 :  गुणधर्म
#
# 	sentence  332 :  दिखाएं
#
# 	sentence  333 :  संबंध
#
# 	sentence  334 :  पहुंचनीय
#
# 	sentence  335 :  कार्रवाई संपन्न करें
#
# 	sentence  336 :  आईडी
#
# 	sentence  337 :  औजार बक्सा
#
# 	sentence  338 :  संस्करण
#
# 	sentence  339 :  अनुप्रयोग
#
# 	sentence  340 :  संग्रह
#
# 	sentence  341 :  0, 0
#
# 	sentence  342 :  सापेक्ष स्थिति
#
# 	sentence  343 :  आकार
#
# 	sentence  344 :  विडजेट
#
# 	sentence  345 :  स्तर
#
# 	sentence  346 :  एमडीआई-जेड-क्रम
#
# 	sentence  347 :  अल्फा
#
# 	sentence  348 :  निरपेक्ष स्थिति
#
# 	sentence  349 :  घटक
#
# 	sentence  350 :  डेस्कटोप
#
# 	sentence  351 :  स्थान-विशिष्टः
#
# 	sentence  352 :  प्रलेख
#
# 	sentence  353 :  हाइपरकड़ी
#
# 	sentence  354 :  हाइपरपाठ
#
# 	sentence  355 :  स्थिति
#
# 	sentence  356 :  स्थान-विशिष्ट
#
# 	sentence  357 :  प्रवेश सहायक
#
# 	sentence  358 :  सभी चुनें
#
# 	sentence  359 :  प्रवाहित करनेयोग्य विषयवस्तु
#
# 	sentence  360 :  शीर्षकः
#
# 	sentence  361 :  सारांशः
#
# 	sentence  362 :  चुने गए स्तंभ
#
# 	sentence  363 :  चुनी गई पंक्तियां
#
# 	sentence  364 :  स्तंभ
#
# 	sentence  365 :  पंक्तियां
#
# 	sentence  366 :  सारणी सूचना
#
# 	sentence  367 :  शीर्षकः
#
# 	sentence  368 :  विस्तारः
#
# 	sentence  369 :  पंक्ति
#
# 	sentence  370 :  स्तंभ
#
# 	sentence  371 :  चुनी गई कोशिका
#
# 	sentence  372 :  ओफसेट
#
# 	sentence  373 :  प्रारंभ
#
# 	sentence  374 :  अंतः 0
#
# 	sentence  375 :  मौजूदा मान
#
# 	sentence  376 :  न्यूनतम वृद्धि
#
# 	sentence  377 :  अधिकतम मान
#
# 	sentence  378 :  न्यूनतम मान
#
# 	sentence  379 :  मान
#
# 	sentence  380 :  अज्ञात
#
# 	sentence  381 :  अंतराफलक दर्शक
#
# 	sentence  382 :  नाम
#
# 	sentence  383 :  यूआरआई
#
# 	sentence  384 :  प्रारंभ
#
# 	sentence  385 :  अंत
#
# 	sentence  386 :  बहुत अधिक चयनीय शिशु हैं
#
# 	sentence  387 :  प्रारंभEnd
#
# 	sentence  388 :  तेज चुनाव
#
# 	sentence  389 :  माउस के अधीन जो एक्सेसेबल है, उसे जांचें
#
# 	sentence  390 :  स्कीमाः
#
# cluster  1 :
# 	sentence  0 :  इस समय जिसे प्राप्त किया गया हो, उसकी विभिन्न विधियों (मेथड) में विचरण करें
#
# 	sentence  1 :  कार्रवाई (_ o)
#
# 	sentence  2 :  छवि (_ I)
#
# 	sentence  3 :  चयन (_ S)
#
# 	sentence  4 :  नाम (x, y)
#
# 	sentence  5 :  सारणी (_ T)
#
# 	sentence  6 :  पाठ (_ x)
#
# 	sentence  7 :  (क्रियान्वित नहीं हुआ है)
#
# 	sentence  8 :  वर्तमान लिपि (स्क्रिप्ट) खो जाएगी।
#
# 	sentence  9 :  % (rolename) s सूची% (num) d पंक्ति और स्तंभ से मेल नहीं खातेparent indexrow and column index
#
# 	sentence  10 :  % (rolename) s अभिभावक सूची% (num1) d पंक्ति और स्तंभ सूची% (num2) d से मेल नहीं खाते
#
# 	sentence  11 :  पसंद (_ P)...
#
# 	sentence  12 :  विषय सूची (_ C)
#
# 	sentence  13 :  टिप्पणीः परिवर्तन सत्रांत (लोगआउट) के बाद ही प्रभाव में आएंगे।
#
# 	sentence  14 :  पंजी ताजा करें (_ R)
#
# 	sentence  15 :  रविशंकर श्रीवास्तव (raviratlami @yahoo. com) राजेश रंजन (rajeshkajha @yahoo. com) ल. बालसुब्रमण्यम (l. balasubramaniam @gmail. com)
#
# 	sentence  16 :  एक्सेर्साइसर सर्वाधिकार © 2006,2007 आईबीएम निगम (बीएसडी)
#
# 	sentence  17 :  पसंद जोड़ें... (_ A)
#
# 	sentence  18 :  पुस्तक चिह्न संपादित करें (_ E)...
#
# 	sentence  19 :  प्लग-इन दृश्य (% d)
#
# 	sentence  20 :  फाइल (F)
#
# 	sentence  21 :  पुस्तक-चिह्न संपादित करें (_ E)...
#
# 	sentence  22 :  दृश्य _ (V)
#
# 	sentence  23 :  इस समय जिसे प्राप्त किया गया हो, उसकी विभिन्न विधियों (मेथड) में विचरण करें
#
# 	sentence  24 :  कार्रवाई (_ o)
#
# 	sentence  25 :  छवि (_ I)
#
# 	sentence  26 :  चयन (_ S)
#
# 	sentence  27 :  नाम (x, y)
#
# 	sentence  28 :  सारणी (_ T)
#
# 	sentence  29 :  पाठ (_ x)
#
# 	sentence  30 :  (क्रियान्वित नहीं हुआ है)
#
# 	sentence  31 :  वर्तमान लिपि (स्क्रिप्ट) खो जाएगी।
#
# 	sentence  32 :  % (rolename) s सूची% (num) d पंक्ति और स्तंभ से मेल नहीं खातेparent indexrow and column index
#
# 	sentence  33 :  % (rolename) s अभिभावक सूची% (num1) d पंक्ति और स्तंभ सूची% (num2) d से मेल नहीं खाते
#
# 	sentence  34 :  पसंद (_ P)...
#
# 	sentence  35 :  विषय सूची (_ C)
#
# 	sentence  36 :  टिप्पणीः परिवर्तन सत्रांत (लोगआउट) के बाद ही प्रभाव में आएंगे।
#
# 	sentence  37 :  पंजी ताजा करें (_ R)
#
# 	sentence  38 :  रविशंकर श्रीवास्तव (raviratlami @yahoo. com) राजेश रंजन (rajeshkajha @yahoo. com) ल. बालसुब्रमण्यम (l. balasubramaniam @gmail. com)
#
# 	sentence  39 :  एक्सेर्साइसर सर्वाधिकार © 2006,2007 आईबीएम निगम (बीएसडी)
#
# 	sentence  40 :  पसंद जोड़ें... (_ A)
#
# 	sentence  41 :  पुस्तक चिह्न संपादित करें (_ E)...
#
# 	sentence  42 :  प्लग-इन दृश्य (% d)
#
# 	sentence  43 :  फाइल (F)
#
# 	sentence  44 :  पुस्तक-चिह्न संपादित करें (_ E)...
#
# 	sentence  45 :  दृश्य _ (V)
#
# 	sentence  46 :  इस समय जिसे प्राप्त किया गया हो, उसकी विभिन्न विधियों (मेथड) में विचरण करें
#
# 	sentence  47 :  कार्रवाई (_ o)
#
# 	sentence  48 :  छवि (_ I)
#
# 	sentence  49 :  चयन (_ S)
#
# 	sentence  50 :  नाम (x, y)
#
# 	sentence  51 :  सारणी (_ T)
#
# 	sentence  52 :  पाठ (_ x)
#
# 	sentence  53 :  (क्रियान्वित नहीं हुआ है)
#
# 	sentence  54 :  (संशोधनीय) Start
#
# cluster  2 :
# 	sentence  0 :  अवधि को हाइलाइट रकें
#
# 	sentence  1 :  भराई के रंग को हाइलाइट करें
#
# 	sentence  2 :  निजी गुणों को छिपाएं
#
# 	sentence  3 :  अंतिम प्रविष्ट घटना को हाइलाइट करो
#
# 	sentence  4 :  डिफोल्टों को शामिल करें
#
# 	sentence  5 :  अंतराफलक के विभिन्न गुणों को देखने देता है
#
# 	sentence  6 :  प्लग-इन जिसमें हैं एक्सेसेबेलों को तेजी से चुनने के लिए कई विधियां
#
# 	sentence  7 :  अंतिम बार फोकस किए गए एक्सेसेबल को जांचें
#
# 	sentence  8 :  एक्सेरसाइसर आपके डेस्कटोप में मौजूद अनुप्रयोग नहीं देख पाया। इस समस्या के समाधान के लिए आपको डेस्कटोप पहुंचनीयता को सक्रिय करना होगा। क्या आप इसे सक्रिय करना चाहते हैं?
#
# 	sentence  9 :  सभी को ताजा करें
#
# 	sentence  10 :  चुने गए एक्सेसेबलों को पुस्तक-चिह्नित करें
#
# 	sentence  11 :  पुस्तक-चिह्नों को प्रबंधित करें।
#
# 	sentence  12 :  पुस्तक चिह्नों को संपादित करें...
#
# 	sentence  13 :  अपने अनुप्रयोग को पहुंचनीयता व्यायाम का लाभ दें
#
# 	sentence  14 :  अवधि को हाइलाइट रकें
#
# 	sentence  15 :  भराई के रंग को हाइलाइट करें
#
# 	sentence  16 :  निजी गुणों को छिपाएं
#
# 	sentence  17 :  अंतिम प्रविष्ट घटना को हाइलाइट करो
#
# 	sentence  18 :  डिफोल्टों को शामिल करें
#
# 	sentence  19 :  अंतराफलक के विभिन्न गुणों को देखने देता है
#
# 	sentence  20 :  प्लग-इन जिसमें हैं एक्सेसेबेलों को तेजी से चुनने के लिए कई विधियां
#
# 	sentence  21 :  अंतिम बार फोकस किए गए एक्सेसेबल को जांचें
#
# 	sentence  22 :  एक्सेरसाइसर आपके डेस्कटोप में मौजूद अनुप्रयोग नहीं देख पाया। इस समस्या के समाधान के लिए आपको डेस्कटोप पहुंचनीयता को सक्रिय करना होगा। क्या आप इसे सक्रिय करना चाहते हैं?
#
# 	sentence  23 :  सभी को ताजा करें
#
# 	sentence  24 :  चुने गए एक्सेसेबलों को पुस्तक-चिह्नित करें
#
# 	sentence  25 :  पुस्तक-चिह्नों को प्रबंधित करें।
#
# 	sentence  26 :  पुस्तक चिह्नों को संपादित करें...
#
# 	sentence  27 :  अपने अनुप्रयोग को पहुंचनीयता व्यायाम का लाभ दें
#
# 	sentence  28 :  अवधि को हाइलाइट रकें
#
# 	sentence  29 :  पहुंचनीय आसंधि नोड को चुनते समय हाइलाइट बक्से की अवधि.
#
# 	sentence  30 :  भराई के रंग को हाइलाइट करें
#
# 	sentence  31 :  निजी गुणों को छिपाएं
#
# 	sentence  32 :  अंतिम प्रविष्ट घटना को हाइलाइट करो
#
# 	sentence  33 :  डिफोल्टों को शामिल करें
#
# 	sentence  34 :  अंतराफलक के विभिन्न गुणों को देखने देता है
#
# 	sentence  35 :  प्लग-इन जिसमें हैं एक्सेसेबेलों को तेजी से चुनने के लिए कई विधियां
#
# 	sentence  36 :  अंतिम बार फोकस किए गए एक्सेसेबल को जांचें
#
# cluster  3 :
# 	sentence  0 :  पहुंचनीय आसंधि (नोड) को चुनते समय हाइलाइट बक्से की अवधि
#
# 	sentence  1 :  सीमांत (बोर्डर) के रंग को हाइलाइट करें
#
# 	sentence  2 :  घटनाओं को मानिटर करें (_ M)
#
# 	sentence  3 :  चुनाव को हटाएं (C _)
#
# 	sentence  4 :  आसंधि (नोड) को ताजा करें (_ N)
#
# 	sentence  5 :  चुनी गई आसंधियों (नोड) के शिशुओं को ताजा करें
#
# 	sentence  6 :  पहुंचनीय आसंधि (नोड) को चुनते समय हाइलाइट बक्से की अवधि
#
# 	sentence  7 :  सीमांत (बोर्डर) के रंग को हाइलाइट करें
#
# 	sentence  8 :  घटनाओं को मानिटर करें (_ M)
#
# 	sentence  9 :  चुनाव को हटाएं (C _)
#
# 	sentence  10 :  आसंधि (नोड) को ताजा करें (_ N)
#
# 	sentence  11 :  चुनी गई आसंधियों (नोड) के शिशुओं को ताजा करें
#
# 	sentence  12 :  सीमांत (बोर्डर) के रंग को हाइलाइट करें
#
# 	sentence  13 :  घटनाओं को मानिटर करें (_ M)
#
# 	sentence  14 :  चुनाव को हटाएं (C _)

# %%
fp = open("en.txt", "r+")
documents = fp.readlines()[1:-1]
print(documents)
# Out:
# ['Accerciser Accessibility Explorer\n', 'The default plugin layout for the bottom panel\n', 'The default plugin layout for the top panel\n', 'A list of plugins that are disabled by default\n', 'Highlight duration\n', 'The duration of the highlight box when selecting accessible nodes\n', 'Highlight border color\n', 'The color and opacity of the highlight border.\n', 'Highlight fill color\n', 'The color and opacity of the highlight fill.\n', 'API Browser\n', 'Browse the various methods of the current accessible\n', 'Hide private attributes\n', 'Method\n', 'Property\n', 'Value\n', 'IPython Console\n', 'Interactive console for manipulating currently selected accessible\n', 'Event monitor\n', '_ Monitor Events\n', 'C _ lear Selection\n', 'Everything\n', 'Selected application\n', 'Selected accessible\n', 'Source\n', 'Event Monitor\n', 'Shows events as they occur from selected types and sources\n', 'Highlight last event entry\n', 'Start / stop event recording\n', 'Clear event log\n', '(no description)\n', 'Description\n', 'Show\n', '_ Accessible\n', 'Perform action\n', 'Acti _ on\n', 'ID\n', 'Toolkit\n', 'Version\n', 'Ap _ plication\n', 'Col _ lection\n', '0, 0\n', 'Relative position\n', 'Size\n', 'WIDGET\n', 'Layer\n', 'MDI - Z - order\n', 'Alpha\n', 'Absolute position\n', 'Co _ mponent\n', 'Des _ ktop\n', 'Locale:\n', '_ Document\n', 'Hyperlink\n', 'H _ ypertext\n', 'Position\n', 'Description\n', 'Locale\n', '_ Image\n', 'Lo _ gin Helper\n', 'Select All\n', '_ Selection\n', 'St _ reamable Content\n', 'Selected columns\n', 'Selected rows\n', 'Columns\n', 'Rows\n', 'Table Information\n', 'name (x, y)\n', 'Header:\n', 'Extents:\n', 'Row\n', 'Column\n', 'Selected Cell\n', '_ Table\n', 'Offset\n', 'Include defaults\n', 'Te _ xt\n', 'Current value\n', 'Minimum increment\n', 'Maximum value\n', 'Minimum value\n', 'Val _ ue\n', 'Interface Viewer\n', 'Allows viewing of various interface properties\n', '(not implemented)\n', 'Name\n', 'URI\n', 'Start\n', 'End\n', 'Too many selectable children\n', 'Quick Select\n', 'Plugin with various methods of selecting accessibles quickly.\n', 'Inspect last focused accessible\n', 'Inspect accessible under mouse\n', 'Native\n', 'Dogtail\n', 'LDTP\n', 'Script Type\n', 'Script Recorder\n', 'Creates dogtail style scripts\n', 'The current script will be lost.\n', 'Confirm clear\n', 'Sche _ ma:\n', 'V _ alidate\n', 'Idle\n', 'No description\n', 'AT - SPI Validator\n', 'Validates application accessibility\n', 'Level\n', 'Role\n', 'Saving\n', 'Validating\n', 'EXCEPT\n', 'ERROR\n', 'WARN\n', 'INFO\n', 'DEBUG\n', 'Basic\n', 'Tests fundamental GUI application accessibility\n', 'actionable% s is not focusable or selectable\n', 'interactive% s is not actionable\n', 'more than one focused widget\n', '% s has no text interface\n', '% s index in parent does not match child index\n', 'Missing reciprocal for% s relation\n', '% s missing name or label\n', 'focusable% s has table interface, no selection interface\n', '% s has% s state without% s state\n', '% s does not belong to a set\n', '% (rolename) s index% (num) d does not match row and column\n', '% (rolename) s parent index% (num1) d does not match row and column index% (num2) d\n', '% s has no name or description\n', '_ Preferences...\n', '_ Contents\n', 'Accerciser could not see the applications on your desktop. You must enable desktop accessibility to fix this problem. Do you want to enable it now?\n', 'Note: Changes only take effect after logout.\n', 'Children\n', '_ Refresh Registry\n', 'Refresh all\n', 'Refresh _ Node\n', "Refresh selected node 's children\n", 'Component\n', 'Task\n', 'Key\n', 'Alt\n', 'Ctrl\n', 'Shift\n', 'Top panel\n', 'Bottom panel\n', 'accerciser Preferences\n', 'Plugins\n', 'Global Hotkeys\n', 'Highlighting\n', 'Highlight duration:\n', 'Border color:\n', 'The border color of the highlight box\n', 'Fill color:\n', 'The fill color of the highlight box\n', 'translator - credits\n', 'An interactive Python accessibility explorer\n', 'accerciser C ...

# %%
    import collections
    from nltk import word_tokenize
    from nltk.corpus import stopwords
    from nltk.stem import PorterStemmer
    from sklearn.cluster import KMeans
    from sklearn.feature_extraction.text import TfidfVectorizer
    from pprint import pprint


    def word_tokenizer(text):
            #tokenizes and stems the text
            tokens = word_tokenize(text)
            stemmer = PorterStemmer()
            tokens = [stemmer.stem(t) for t in tokens if t not in stopwords.words('english')]
            return tokens


    def cluster_sentences(sentences, nb_of_clusters=5):
            tfidf_vectorizer = TfidfVectorizer(tokenizer=word_tokenizer,
                                            stop_words=stopwords.words('english'),
                                            max_df=0.9,
                                            min_df=0.1,
                                            lowercase=True)
            #builds a tf-idf matrix for the sentences
            tfidf_matrix = tfidf_vectorizer.fit_transform(sentences)
            kmeans = KMeans(n_clusters=nb_of_clusters)
            kmeans.fit(tfidf_matrix)
            clusters = collections.defaultdict(list)
            for i, label in enumerate(kmeans.labels_):
                    clusters[label].append(i)
            return dict(clusters)


    if __name__ == "__main__":
#            
            nclusters= 4
            clusters = cluster_sentences(documents, nclusters)
            for cluster in range(nclusters):
                    print("cluster ",cluster,":")
                    for i,sentence in enumerate(clusters[cluster]):
                            print("\tsentence ",i,": ",documents[sentence])
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/feature_extraction/text.py:300: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ["'d", "'ll", "'re", "'s", "'ve", 'could', 'might', 'must', "n't", 'need', 'sha', 'wo', 'would'] not in stop_words.
#   'stop_words.' % sorted(inconsistent))
# cluster  0 :
# 	sentence  0 :  Accerciser Accessibility Explorer
#
# 	sentence  1 :  The default plugin layout for the bottom panel
#
# 	sentence  2 :  The default plugin layout for the top panel
#
# 	sentence  3 :  A list of plugins that are disabled by default
#
# 	sentence  4 :  Highlight duration
#
# 	sentence  5 :  Highlight border color
#
# 	sentence  6 :  The color and opacity of the highlight border.
#
# 	sentence  7 :  Highlight fill color
#
# 	sentence  8 :  The color and opacity of the highlight fill.
#
# 	sentence  9 :  API Browser
#
# 	sentence  10 :  Browse the various methods of the current accessible
#
# 	sentence  11 :  Hide private attributes
#
# 	sentence  12 :  Method
#
# 	sentence  13 :  Property
#
# 	sentence  14 :  Value
#
# 	sentence  15 :  IPython Console
#
# 	sentence  16 :  Event monitor
#
# 	sentence  17 :  Everything
#
# 	sentence  18 :  Source
#
# 	sentence  19 :  Event Monitor
#
# 	sentence  20 :  Highlight last event entry
#
# 	sentence  21 :  Start / stop event recording
#
# 	sentence  22 :  Clear event log
#
# 	sentence  23 :  (no description)
#
# 	sentence  24 :  Description
#
# 	sentence  25 :  Show
#
# 	sentence  26 :  Perform action
#
# 	sentence  27 :  ID
#
# 	sentence  28 :  Toolkit
#
# 	sentence  29 :  Version
#
# 	sentence  30 :  0, 0
#
# 	sentence  31 :  Relative position
#
# 	sentence  32 :  Size
#
# 	sentence  33 :  WIDGET
#
# 	sentence  34 :  Layer
#
# 	sentence  35 :  MDI - Z - order
#
# 	sentence  36 :  Alpha
#
# 	sentence  37 :  Absolute position
#
# 	sentence  38 :  Locale:
#
# 	sentence  39 :  Hyperlink
#
# 	sentence  40 :  Position
#
# 	sentence  41 :  Description
#
# 	sentence  42 :  Locale
#
# 	sentence  43 :  Columns
#
# 	sentence  44 :  Rows
#
# 	sentence  45 :  Table Information
#
# 	sentence  46 :  name (x, y)
#
# 	sentence  47 :  Header:
#
# 	sentence  48 :  Extents:
#
# 	sentence  49 :  Row
#
# 	sentence  50 :  Column
#
# 	sentence  51 :  Offset
#
# 	sentence  52 :  Include defaults
#
# 	sentence  53 :  Current value
#
# 	sentence  54 :  Minimum increment
#
# 	sentence  55 :  Maximum value
#
# 	sentence  56 :  Minimum value
#
# 	sentence  57 :  Interface Viewer
#
# 	sentence  58 :  Allows viewing of various interface properties
#
# 	sentence  59 :  (not implemented)
#
# 	sentence  60 :  Name
#
# 	sentence  61 :  URI
#
# 	sentence  62 :  Start
#
# 	sentence  63 :  End
#
# 	sentence  64 :  Inspect last focused accessible
#
# 	sentence  65 :  Inspect accessible under mouse
#
# 	sentence  66 :  Native
#
# 	sentence  67 :  Dogtail
#
# 	sentence  68 :  LDTP
#
# 	sentence  69 :  Script Type
#
# 	sentence  70 :  Script Recorder
#
# 	sentence  71 :  Creates dogtail style scripts
#
# 	sentence  72 :  The current script will be lost.
#
# 	sentence  73 :  Confirm clear
#
# 	sentence  74 :  Idle
#
# 	sentence  75 :  No description
#
# 	sentence  76 :  AT - SPI Validator
#
# 	sentence  77 :  Validates application accessibility
#
# 	sentence  78 :  Level
#
# 	sentence  79 :  Role
#
# 	sentence  80 :  Saving
#
# 	sentence  81 :  Validating
#
# 	sentence  82 :  EXCEPT
#
# 	sentence  83 :  ERROR
#
# 	sentence  84 :  WARN
#
# 	sentence  85 :  INFO
#
# 	sentence  86 :  DEBUG
#
# 	sentence  87 :  Basic
#
# 	sentence  88 :  Tests fundamental GUI application accessibility
#
# 	sentence  89 :  interactive% s is not actionable
#
# 	sentence  90 :  more than one focused widget
#
# 	sentence  91 :  % s has no text interface
#
# 	sentence  92 :  % s index in parent does not match child index
#
# 	sentence  93 :  Missing reciprocal for% s relation
#
# 	sentence  94 :  % s missing name or label
#
# 	sentence  95 :  % s has% s state without% s state
#
# 	sentence  96 :  % s does not belong to a set
#
# 	sentence  97 :  % (rolename) s index% (num) d does not match row and column
#
# 	sentence  98 :  % (rolename) s parent index% (num1) d does not match row and column index% (num2) d
#
# 	sentence  99 :  % s has no name or description
#
# 	sentence  100 :  Accerciser could not see the applications on your desktop. You must enable desktop accessibility to fix this problem. Do you want to enable it now?
#
# 	sentence  101 :  Note: Changes only take effect after logout.
#
# 	sentence  102 :  Children
#
# 	sentence  103 :  Refresh all
#
# 	sentence  104 :  Component
#
# 	sentence  105 :  Task
#
# 	sentence  106 :  Key
#
# 	sentence  107 :  Alt
#
# 	sentence  108 :  Ctrl
#
# 	sentence  109 :  Shift
#
# 	sentence  110 :  Top panel
#
# 	sentence  111 :  Bottom panel
#
# 	sentence  112 :  accerciser Preferences
#
# 	sentence  113 :  Plugins
#
# 	sentence  114 :  Global Hotkeys
#
# 	sentence  115 :  Highlighting
#
# 	sentence  116 :  Highlight duration:
#
# 	sentence  117 :  Border color:
#
# 	sentence  118 :  The border color of the highlight box
#
# 	sentence  119 :  Fill color:
#
# 	sentence  120 :  The fill color of the highlight box
#
# 	sentence  121 :  translator - credits
#
# 	sentence  122 :  An interactive Python accessibility explorer
#
# 	sentence  123 :  accerciser Copyright © 2006, 2007 IBM Corporation (BSD)
#
# 	sentence  124 :  The New BSD License See the COPYING and NOTICE files for details.
#
# 	sentence  125 :  Web site
#
# 	sentence  126 :  Manage bookmarks.
#
# 	sentence  127 :  Edit Bookmarks...
#
# 	sentence  128 :  Title
#
# 	sentence  129 :  Application
#
# 	sentence  130 :  Path
#
# 	sentence  131 :  Add Bookmark...
#
# 	sentence  132 :  Title:
#
# 	sentence  133 :  Application:
#
# 	sentence  134 :  Path:
#
# 	sentence  135 :  Plugin Errors
#
# 	sentence  136 :  View
#
# 	sentence  137 :  No view
#
# 	sentence  138 :  Plugin View
#
# 	sentence  139 :  Plugin View (% d)
#
# 	sentence  140 :  New View...
#
# 	sentence  141 :  Full name
#
# 	sentence  142 :  Key binding
#
# 	sentence  143 :  Content type
#
# 	sentence  144 :  Give your application an accessibility workout
#
# 	sentence  145 :  Accerciser Accessibility Explorer
#
# 	sentence  146 :  The default plugin layout for the bottom panel
#
# 	sentence  147 :  The default plugin layout for the top panel
#
# 	sentence  148 :  A list of plugins that are disabled by default
#
# 	sentence  149 :  Highlight duration
#
# 	sentence  150 :  Highlight border color
#
# 	sentence  151 :  The color and opacity of the highlight border.
#
# 	sentence  152 :  Highlight fill color
#
# 	sentence  153 :  The color and opacity of the highlight fill.
#
# 	sentence  154 :  API Browser
#
# 	sentence  155 :  Browse the various methods of the current accessible
#
# 	sentence  156 :  Hide private attributes
#
# 	sentence  157 :  Method
#
# 	sentence  158 :  Property
#
# 	sentence  159 :  Value
#
# 	sentence  160 :  IPython Console
#
# 	sentence  161 :  Event monitor
#
# 	sentence  162 :  Everything
#
# 	sentence  163 :  Source
#
# 	sentence  164 :  Event Monitor
#
# 	sentence  165 :  Highlight last event entry
#
# 	sentence  166 :  Start / stop event recording
#
# 	sentence  167 :  Clear event log
#
# 	sentence  168 :  (no description)
#
# 	sentence  169 :  Description
#
# 	sentence  170 :  Show
#
# 	sentence  171 :  Perform action
#
# 	sentence  172 :  ID
#
# 	sentence  173 :  Toolkit
#
# 	sentence  174 :  Version
#
# 	sentence  175 :  0, 0
#
# 	sentence  176 :  Relative position
#
# 	sentence  177 :  Size
#
# 	sentence  178 :  WIDGET
#
# 	sentence  179 :  Layer
#
# 	sentence  180 :  MDI - Z - order
#
# 	sentence  181 :  Alpha
#
# 	sentence  182 :  Absolute position
#
# 	sentence  183 :  Locale:
#
# 	sentence  184 :  Hyperlink
#
# 	sentence  185 :  Position
#
# 	sentence  186 :  Description
#
# 	sentence  187 :  Locale
#
# 	sentence  188 :  Columns
#
# 	sentence  189 :  Rows
#
# 	sentence  190 :  Table Information
#
# 	sentence  191 :  name (x, y)
#
# 	sentence  192 :  Header:
#
# 	sentence  193 :  Extents:
#
# 	sentence  194 :  Row
#
# 	sentence  195 :  Column
#
# 	sentence  196 :  Offset
#
# 	sentence  197 :  Include defaults
#
# 	sentence  198 :  Current value
#
# 	sentence  199 :  Minimum increment
#
# 	sentence  200 :  Maximum value
#
# 	sentence  201 :  Minimum value
#
# 	sentence  202 :  Interface Viewer
#
# 	sentence  203 :  Allows viewing of various interface properties
#
# 	sentence  204 :  (not implemented)
#
# 	sentence  205 :  Name
#
# 	sentence  206 :  URI
#
# 	sentence  207 :  Start
#
# 	sentence  208 :  End
#
# 	sentence  209 :  Inspect last focused accessible
#
# 	sentence  210 :  Inspect accessible under mouse
#
# 	sentence  211 :  Native
#
# 	sentence  212 :  Dogtail
#
# 	sentence  213 :  LDTP
#
# 	sentence  214 :  Script Type
#
# 	sentence  215 :  Script Recorder
#
# 	sentence  216 :  Creates dogtail style scripts
#
# 	sentence  217 :  The current script will be lost.
#
# 	sentence  218 :  Confirm clear
#
# 	sentence  219 :  Idle
#
# 	sentence  220 :  No description
#
# 	sentence  221 :  AT - SPI Validator
#
# 	sentence  222 :  Validates application accessibility
#
# 	sentence  223 :  Level
#
# 	sentence  224 :  Role
#
# 	sentence  225 :  Saving
#
# 	sentence  226 :  Validating
#
# 	sentence  227 :  EXCEPT
#
# 	sentence  228 :  ERROR
#
# 	sentence  229 :  WARN
#
# 	sentence  230 :  INFO
#
# 	sentence  231 :  DEBUG
#
# 	sentence  232 :  Basic
#
# 	sentence  233 :  Tests fundamental GUI application accessibility
#
# 	sentence  234 :  interactive% s is not actionable
#
# 	sentence  235 :  more than one focused widget
#
# 	sentence  236 :  % s has no text interface
#
# 	sentence  237 :  % s index in parent does not match child index
#
# 	sentence  238 :  Missing reciprocal for% s relation
#
# 	sentence  239 :  % s missing name or label
#
# 	sentence  240 :  % s has% s state without% s state
#
# 	sentence  241 :  % s does not belong to a set
#
# 	sentence  242 :  % (rolename) s index% (num) d does not match row and column
#
# 	sentence  243 :  % (rolename) s parent index% (num1) d does not match row and column index% (num2) d
#
# 	sentence  244 :  % s has no name or description
#
# 	sentence  245 :  Accerciser could not see the applications on your desktop. You must enable desktop accessibility to fix this problem. Do you want to enable it now?
#
# 	sentence  246 :  Note: Changes only take effect after logout.
#
# 	sentence  247 :  Children
#
# 	sentence  248 :  Refresh all
#
# 	sentence  249 :  Component
#
# 	sentence  250 :  Task
#
# 	sentence  251 :  Key
#
# 	sentence  252 :  Alt
#
# 	sentence  253 :  Ctrl
#
# 	sentence  254 :  Shift
#
# 	sentence  255 :  Top panel
#
# 	sentence  256 :  Bottom panel
#
# 	sentence  257 :  accerciser Preferences
#
# 	sentence  258 :  Plugins
#
# 	sentence  259 :  Global Hotkeys
#
# 	sentence  260 :  Highlighting
#
# 	sentence  261 :  Highlight duration:
#
# 	sentence  262 :  Border color:
#
# 	sentence  263 :  The border color of the highlight box
#
# 	sentence  264 :  Fill color:
#
# 	sentence  265 :  The fill color of the highlight box
#
# 	sentence  266 :  translator - credits
#
# 	sentence  267 :  An interactive Python accessibility explorer
#
# 	sentence  268 :  accerciser Copyright © 2006, 2007 IBM Corporation (BSD)
#
# 	sentence  269 :  The New BSD License See the COPYING and NOTICE files for details.
#
# 	sentence  270 :  Web site
#
# 	sentence  271 :  Manage bookmarks.
#
# 	sentence  272 :  Edit Bookmarks...
#
# 	sentence  273 :  Title
#
# 	sentence  274 :  Application
#
# 	sentence  275 :  Path
#
# 	sentence  276 :  Add Bookmark...
#
# 	sentence  277 :  Title:
#
# 	sentence  278 :  Application:
#
# 	sentence  279 :  Path:
#
# 	sentence  280 :  Plugin Errors
#
# 	sentence  281 :  View
#
# 	sentence  282 :  No view
#
# 	sentence  283 :  Plugin View
#
# 	sentence  284 :  Plugin View (% d)
#
# 	sentence  285 :  New View...
#
# 	sentence  286 :  Full name
#
# 	sentence  287 :  Key binding
#
# 	sentence  288 :  Content type
#
# 	sentence  289 :  Accerciser
#
# 	sentence  290 :  Give your application an accessibility workout
#
# 	sentence  291 :  Accerciser Accessibility Explorer
#
# 	sentence  292 :  A list of plugins that are disabled by default
#
# 	sentence  293 :  A list of plugins that are disabled by default.
#
# 	sentence  294 :  Highlight duration
#
# 	sentence  295 :  Highlight fill color
#
# 	sentence  296 :  The color and opacity of the highlight fill.
#
# 	sentence  297 :  Highlight border color
#
# 	sentence  298 :  The color and opacity of the highlight border.
#
# 	sentence  299 :  The layout for the bottom panel
#
# 	sentence  300 :  The layout for the bottom panel pluginview.
#
# 	sentence  301 :  The layout for the top panel
#
# 	sentence  302 :  The layout for the top panel pluginview.
#
# 	sentence  303 :  Single layout view
#
# 	sentence  304 :  Available new pluginviews
#
# 	sentence  305 :  The default plugin layout for the top panel.
#
# 	sentence  306 :  API Browser
#
# 	sentence  307 :  Browse the various methods of the current accessible
#
# 	sentence  308 :  Hide private attributes
#
# 	sentence  309 :  Method
#
# 	sentence  310 :  Property
#
# 	sentence  311 :  Value
#
# 	sentence  312 :  IPython Console
#
# 	sentence  313 :  Event monitor
#
# 	sentence  314 :  Everything
#
# 	sentence  315 :  Source
#
# 	sentence  316 :  Event Monitor
#
# 	sentence  317 :  Highlight last event entry
#
# 	sentence  318 :  Start / stop event recording
#
# 	sentence  319 :  Clear event log
#
# 	sentence  320 :  Child count
#
# 	sentence  321 :  Description
#
# 	sentence  322 :  States
#
# 	sentence  323 :  Attributes
#
# 	sentence  324 :  Show
#
# 	sentence  325 :  Relations
#
# 	sentence  326 :  Perform action
#
# 	sentence  327 :  ID
#
# 	sentence  328 :  Toolkit
#
# 	sentence  329 :  Version
#
# 	sentence  330 :  0, 0
#
# 	sentence  331 :  Relative position
#
# 	sentence  332 :  Size
#
# 	sentence  333 :  WIDGET
#
# 	sentence  334 :  Layer
#
# 	sentence  335 :  MDI - Z - order
#
# 	sentence  336 :  Alpha
#
# 	sentence  337 :  Absolute position
#
# 	sentence  338 :  Locale:
#
# 	sentence  339 :  Hyperlink
#
# 	sentence  340 :  Position
#
# 	sentence  341 :  Locale
#
# 	sentence  342 :  Caption:
#
# 	sentence  343 :  Summary:
#
# 	sentence  344 :  Columns
#
# 	sentence  345 :  Rows
#
# 	sentence  346 :  Table Information
#
# 	sentence  347 :  name (x, y)
#
# 	sentence  348 :  Header:
#
# 	sentence  349 :  Extents:
#
# 	sentence  350 :  Row
#
# 	sentence  351 :  Column
#
# 	sentence  352 :  Offset
#
# 	sentence  353 :  Include defaults
#
# 	sentence  354 :  Start: 0
#
# 	sentence  355 :  End: 0
#
# 	sentence  356 :  Current value
#
# 	sentence  357 :  Minimum increment
#
# 	sentence  358 :  Maximum value
#
# 	sentence  359 :  Minimum value
#
# 	sentence  360 :  unknown
#
# 	sentence  361 :  Interface Viewer
#
# 	sentence  362 :  Allows viewing of various interface properties
#
# 	sentence  363 :  (not implemented)
#
# 	sentence  364 :  Name
#
# 	sentence  365 :  URI
#
# 	sentence  366 :  Start
#
# 	sentence  367 :  End
#
# 	sentence  368 :  (Editable)
#
# 	sentence  369 :  Start:% d
#
# 	sentence  370 :  Inspect last focused accessible
#
# 	sentence  371 :  Inspect accessible under mouse
#
# cluster  1 :
# 	sentence  0 :  _ Monitor Events
#
# 	sentence  1 :  _ Accessible
#
# 	sentence  2 :  Acti _ on
#
# 	sentence  3 :  Ap _ plication
#
# 	sentence  4 :  Col _ lection
#
# 	sentence  5 :  Co _ mponent
#
# 	sentence  6 :  Des _ ktop
#
# 	sentence  7 :  _ Document
#
# 	sentence  8 :  H _ ypertext
#
# 	sentence  9 :  _ Image
#
# 	sentence  10 :  Lo _ gin Helper
#
# 	sentence  11 :  St _ reamable Content
#
# 	sentence  12 :  _ Table
#
# 	sentence  13 :  Te _ xt
#
# 	sentence  14 :  Val _ ue
#
# 	sentence  15 :  Sche _ ma:
#
# 	sentence  16 :  V _ alidate
#
# 	sentence  17 :  _ Preferences...
#
# 	sentence  18 :  _ Contents
#
# 	sentence  19 :  _ Refresh Registry
#
# 	sentence  20 :  Refresh _ Node
#
# 	sentence  21 :  _ Add Bookmark...
#
# 	sentence  22 :  _ Edit Bookmarks...
#
# 	sentence  23 :  _ Single plugins view
#
# 	sentence  24 :  _ New view...
#
# 	sentence  25 :  _ File
#
# 	sentence  26 :  _ Edit
#
# 	sentence  27 :  _ Bookmarks
#
# 	sentence  28 :  _ View
#
# 	sentence  29 :  _ Help
#
# 	sentence  30 :  _ Monitor Events
#
# 	sentence  31 :  _ Accessible
#
# 	sentence  32 :  Acti _ on
#
# 	sentence  33 :  Ap _ plication
#
# 	sentence  34 :  Col _ lection
#
# 	sentence  35 :  Co _ mponent
#
# 	sentence  36 :  Des _ ktop
#
# 	sentence  37 :  _ Document
#
# 	sentence  38 :  H _ ypertext
#
# 	sentence  39 :  _ Image
#
# 	sentence  40 :  Lo _ gin Helper
#
# 	sentence  41 :  St _ reamable Content
#
# 	sentence  42 :  _ Table
#
# 	sentence  43 :  Te _ xt
#
# 	sentence  44 :  Val _ ue
#
# 	sentence  45 :  Sche _ ma:
#
# 	sentence  46 :  V _ alidate
#
# 	sentence  47 :  _ Preferences...
#
# 	sentence  48 :  _ Contents
#
# 	sentence  49 :  _ Refresh Registry
#
# 	sentence  50 :  Refresh _ Node
#
# 	sentence  51 :  _ Add Bookmark...
#
# 	sentence  52 :  _ Edit Bookmarks...
#
# 	sentence  53 :  _ Single plugins view
#
# 	sentence  54 :  _ New view...
#
# 	sentence  55 :  _ File
#
# 	sentence  56 :  _ Edit
#
# 	sentence  57 :  _ Bookmarks
#
# 	sentence  58 :  _ View
#
# 	sentence  59 :  _ Help
#
# 	sentence  60 :  _ Monitor Events
#
# 	sentence  61 :  _ Accessible
#
# 	sentence  62 :  Acti _ on
#
# 	sentence  63 :  Ap _ plication
#
# 	sentence  64 :  Col _ lection
#
# 	sentence  65 :  Co _ mponent
#
# 	sentence  66 :  Des _ ktop
#
# 	sentence  67 :  _ Document
#
# 	sentence  68 :  H _ ypertext
#
# 	sentence  69 :  _ Image
#
# 	sentence  70 :  Lo _ gin Helper
#
# 	sentence  71 :  St _ reamable Content
#
# 	sentence  72 :  _ Table
#
# 	sentence  73 :  Te _ xt
#
# 	sentence  74 :  Val _ ue
#
# 	sentence  75 :  Sche _ ma:
#
# cluster  2 :
# 	sentence  0 :  The duration of the highlight box when selecting accessible nodes
#
# 	sentence  1 :  Interactive console for manipulating currently selected accessible
#
# 	sentence  2 :  Selected application
#
# 	sentence  3 :  Selected accessible
#
# 	sentence  4 :  Shows events as they occur from selected types and sources
#
# 	sentence  5 :  Select All
#
# 	sentence  6 :  Selected columns
#
# 	sentence  7 :  Selected rows
#
# 	sentence  8 :  Selected Cell
#
# 	sentence  9 :  Too many selectable children
#
# 	sentence  10 :  Quick Select
#
# 	sentence  11 :  Plugin with various methods of selecting accessibles quickly.
#
# 	sentence  12 :  actionable% s is not focusable or selectable
#
# 	sentence  13 :  focusable% s has table interface, no selection interface
#
# 	sentence  14 :  Refresh selected node 's children
#
# 	sentence  15 :  Bookmark selected accessible.
#
# 	sentence  16 :  The duration of the highlight box when selecting accessible nodes
#
# 	sentence  17 :  Interactive console for manipulating currently selected accessible
#
# 	sentence  18 :  Selected application
#
# 	sentence  19 :  Selected accessible
#
# 	sentence  20 :  Shows events as they occur from selected types and sources
#
# 	sentence  21 :  Select All
#
# 	sentence  22 :  Selected columns
#
# 	sentence  23 :  Selected rows
#
# 	sentence  24 :  Selected Cell
#
# 	sentence  25 :  Too many selectable children
#
# 	sentence  26 :  Quick Select
#
# 	sentence  27 :  Plugin with various methods of selecting accessibles quickly.
#
# 	sentence  28 :  actionable% s is not focusable or selectable
#
# 	sentence  29 :  focusable% s has table interface, no selection interface
#
# 	sentence  30 :  Refresh selected node 's children
#
# 	sentence  31 :  Bookmark selected accessible.
#
# 	sentence  32 :  The duration of the highlight box when selecting accessible nodes.
#
# 	sentence  33 :  Interactive console for manipulating currently selected accessible
#
# 	sentence  34 :  Selected application
#
# 	sentence  35 :  Selected accessible
#
# 	sentence  36 :  Shows events as they occur from selected types and sources
#
# 	sentence  37 :  Select All
#
# 	sentence  38 :  Selected columns
#
# 	sentence  39 :  Selected rows
#
# 	sentence  40 :  Selected Cell
#
# 	sentence  41 :  Too many selectable children
#
# 	sentence  42 :  Quick Select
#
# 	sentence  43 :  Plugin with various methods of selecting accessibles quickly.
#
# cluster  3 :
# 	sentence  0 :  C _ lear Selection
#
# 	sentence  1 :  _ Selection
#
# 	sentence  2 :  C _ lear Selection
#
# 	sentence  3 :  _ Selection
#
# 	sentence  4 :  C _ lear Selection
#
# 	sentence  5 :  _ Selection
